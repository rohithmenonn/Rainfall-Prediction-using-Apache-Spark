# %%
# BigData Project

# %%
# Data exploration and Data Preprocessing

# %%
import findspark
findspark.init()
findspark.find()
# Out:
# 'C:\\Spark\\spark-3.0.1-bin-hadoop2.7'

# %%
import pyspark
from pyspark import SparkConf, SparkContext
from pyspark.sql import SQLContext
sc = SparkContext.getOrCreate();

# %%
sqlContext = SQLContext(sc)

mysore = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/mysore.csv")
bangalore = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/bangalore.csv")
bhopal = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/bhopal.csv")
cherrapunji = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/cherrapunji.csv")
gandhinagar = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/gandhinagar.csv")
gangtok = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/gangtok.csv")
kolkata = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/kolkata.csv")
mawsynram = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/mawsynram.csv")
meerut = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/meerut.csv")
mizoram = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/mizoram.csv")
mumbai = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/mumbai.csv")
pune = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/pune.csv")
rajasthan = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/rajasthan.csv")
shillong = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/shillong.csv")
uttarakhand = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/uttarakhand.csv")
vellore = sqlContext.read.format('csv').options(header='true', inferschema='true').load("C:/Users/Palak Sharma/PALAK's Folder/VIT/Fall Sem 2020-21/CSE6001 - Bigdata Frameworks - LOKESH KUMAR R/Project/data/vellore.csv")

# %%
mysore.cache()
mysore.printSchema()

bangalore.cache()
bangalore.printSchema()
# Out:
# root
#  |-- date_time: string (nullable = true)
#  |-- maxtempC: integer (nullable = true)
#  |-- mintempC: integer (nullable = true)
#  |-- totalSnow_cm: double (nullable = true)
#  |-- sunHour: double (nullable = true)
#  |-- uvIndex: integer (nullable = true)
#  |-- moon_illumination: integer (nullable = true)
#  |-- moonrise: string (nullable = true)
#  |-- moonset: string (nullable = true)
#  |-- sunrise: string (nullable = true)
#  |-- sunset: string (nullable = true)
#  |-- DewPointC: integer (nullable = true)
#  |-- FeelsLikeC: integer (nullable = true)
#  |-- HeatIndexC: integer (nullable = true)
#  |-- WindChillC: integer (nullable = true)
#  |-- WindGustKmph: integer (nullable = true)
#  |-- cloudcover: integer (nullable = true)
#  |-- humidity: integer (nullable = true)
#  |-- precipMM: double (nullable = true)
#  |-- pressure: integer (nullable = true)
#  |-- tempC: integer (nullable = true)
#  |-- visibility: integer (nullable = true)
# ...

# %%
mysore.describe().toPandas().transpose()
# Out:
#                        0                   1                   2  \
# summary            count                mean              stddev
# date_time           7800                None                None
# maxtempC            7800  23.379487179487178  12.634244988223639
# mintempC            7800  21.052307692307693  2.3317236773013934
# totalSnow_cm        7800                 0.0                 0.0
# sunHour             7800  10.244512820512576   2.124058064883714
# uvIndex             7800   5.182564102564102   1.970028951108912
# moon_illumination   7800   46.07282051282051    31.2302901309429
# moonrise            7800                None                None
# moonset             7800                None                None
# sunrise             7800                None                None
# sunset              7800                None                None
# DewPointC           7800   17.26474358974359   3.944191788389013
# ...

# %%
bangalore.describe().toPandas().transpose()
# Out:
#                        0                   1                   2  \
# summary            count                mean              stddev
# date_time           7800                None                None
# maxtempC            7800  29.746666666666666   3.211152936901155
# mintempC            7800  21.026666666666667   2.619486029063772
# totalSnow_cm        7800                 0.0                 0.0
# sunHour             7800  10.371999999999792  2.2249550622090855
# uvIndex             7800   6.282051282051282  0.8837760070897046
# moon_illumination   7800   46.07282051282051    31.2302901309429
# moonrise            7800                None                None
# moonset             7800                None                None
# sunrise             7800                None                None
# sunset              7800                None                None
# DewPointC           7800   15.86628205128205   4.367311641403201
# ...

# %%
bhopal.describe().toPandas().transpose()
# Out:
#                        0                   1                   2  \
# summary            count                mean              stddev
# date_time           7800                None                None
# maxtempC            7800    32.0625641025641   5.889366268560268
# mintempC            7800  22.635897435897437   5.909758053512101
# totalSnow_cm        7800                 0.0                 0.0
# sunHour             7800   10.66133333333306  2.1937238728888717
# uvIndex             7800   6.827692307692308  1.3425110799112154
# moon_illumination   7800   46.07282051282051    31.2302901309429
# moonrise            7800                None                None
# moonset             7800                None                None
# sunrise             7800                None                None
# sunset              7800                None                None
# DewPointC           7800  11.579358974358975   8.824025625174215
# ...

# %%
cherrapunji.describe().toPandas().transpose()
# Out:
#                        0                   1                   2  \
# summary            count                mean              stddev
# date_time           7800                None                None
# maxtempC            7800   21.90051282051282  3.2560279338447637
# mintempC            7800   13.35897435897436   4.201900176995161
# totalSnow_cm        7800                 0.0                 0.0
# sunHour             7800   9.320717948717807  2.1180015347682226
# uvIndex             7800   4.665641025641025  0.7380272108662033
# moon_illumination   7800   46.07282051282051    31.2302901309429
# moonrise            7800                None                None
# moonset             7800                None                None
# sunrise             7800                None                None
# sunset              7800                None                None
# DewPointC           7800  14.912820512820513   5.423714956306431
# ...

# %%
gandhinagar.describe().toPandas().transpose()
# Out:
#                        0                   1                   2  \
# summary            count                mean              stddev
# date_time           7800                None                None
# maxtempC            7800    34.9251282051282   5.229791700428873
# mintempC            7800   24.21128205128205   4.933560465990509
# totalSnow_cm        7800                 0.0                 0.0
# sunHour             7800    10.5640000000002   2.063106557543241
# uvIndex             7800   7.243076923076923  1.1202324091796765
# moon_illumination   7800   46.07282051282051    31.2302901309429
# moonrise            7800                None                None
# moonset             7800                None                None
# sunrise             7800                None                None
# sunset              7800                None                None
# DewPointC           7800  13.682307692307692    8.69593463622687
# ...

# %%
gangtok.describe().toPandas().transpose()
# Out:
#                        0                     1                     2  \
# summary            count                  mean                stddev
# date_time           7800                  None                  None
# maxtempC            7800    17.008205128205127     4.372680267127627
# mintempC            7800     7.305641025641026     5.159630944692689
# totalSnow_cm        7800  3.076923076923077E-4  0.009603376564995285
# sunHour             7800      9.86112820512762    2.3509491000353764
# uvIndex             7800    3.7343589743589742    0.8783991397467077
# moon_illumination   7800     46.07282051282051      31.2302901309429
# moonrise            7800                  None                  None
# moonset             7800                  None                  None
# sunrise             7800                  None                  None
# sunset              7800                  None                  None
# DewPointC           7800     7.157948717948718     8.049718940423237
# ...

# %%
kolkata.describe().toPandas().transpose()
# Out:
#                        0                    1                   2  \
# summary            count                 mean              stddev
# date_time           7800                 None                None
# maxtempC            7800    33.43692307692308   4.305296406172151
# mintempC            7800   24.925128205128207   4.230508426639103
# totalSnow_cm        7800                  0.0                 0.0
# sunHour             7800   10.694974358974129  2.0509437904167758
# uvIndex             7800    7.093333333333334  0.9536006452956121
# moon_illumination   7800    46.07282051282051    31.2302901309429
# moonrise            7800                 None                None
# moonset             7800                 None                None
# sunrise             7800                 None                None
# sunset              7800                 None                None
# DewPointC           7800   19.355128205128207   6.463825134756807
# ...

# %%
mawsynram.describe().toPandas().transpose()
# Out:
#                        0                   1                   2  \
# summary            count                mean              stddev
# date_time           7800                None                None
# maxtempC            7800   21.90051282051282  3.2560279338447637
# mintempC            7800   13.35897435897436   4.201900176995161
# totalSnow_cm        7800                 0.0                 0.0
# sunHour             7800    9.31723076923066    2.12288479416343
# uvIndex             7800   4.665641025641025  0.7380272108662033
# moon_illumination   7800   46.07282051282051    31.2302901309429
# moonrise            7800                None                None
# moonset             7800                None                None
# sunrise             7800                None                None
# sunset              7800                None                None
# DewPointC           7800  14.912820512820513   5.423714956306431
# ...

# %%
meerut.describe().toPandas().transpose()
# Out:
#                        0                    1                   2  \
# summary            count                 mean              stddev
# date_time           7800                 None                None
# maxtempC            7800    32.91487179487179    7.67542187074656
# mintempC            7800   22.583589743589744   7.517773951182082
# totalSnow_cm        7800                  0.0                 0.0
# sunHour             7800    11.22112820512808  2.3655701864320395
# uvIndex             7800    6.914871794871795  1.6480832320489311
# moon_illumination   7800    46.07282051282051    31.2302901309429
# moonrise            7800                 None                None
# moonset             7800                 None                None
# sunrise             7800                 None                None
# sunset              7800                 None                None
# DewPointC           7800    12.36474358974359   8.007748079015988
# ...

# %%
mizoram.describe().toPandas().transpose()
# Out:
#                        0                   1                   2  \
# summary            count                mean              stddev
# date_time           7800                None                None
# maxtempC            7800   30.64205128205128   3.673573372505415
# mintempC            7800   17.39076923076923   4.474499779131444
# totalSnow_cm        7800                 0.0                 0.0
# sunHour             7800  10.289333333333595  1.7911148449814613
# uvIndex             7800   5.938461538461539  0.8714283092568894
# moon_illumination   7800   46.07282051282051    31.2302901309429
# moonrise            7800                None                None
# moonset             7800                None                None
# sunrise             7800                None                None
# sunset              7800                None                None
# DewPointC           7800  16.895384615384614   6.335196438782135
# ...

# %%
mumbai.describe().toPandas().transpose()
# Out:
#                        0                   1                   2  \
# summary            count                mean              stddev
# date_time           7800                None                None
# maxtempC            7800  30.586666666666666   2.062848064662276
# mintempC            7800  25.899487179487178   2.616908681273302
# totalSnow_cm        7800                 0.0                 0.0
# sunHour             7800  10.334564102564446  1.8664433862179612
# uvIndex             7800   6.858461538461539  0.7320744560240524
# moon_illumination   7800   46.07282051282051    31.2302901309429
# moonrise            7800                None                None
# moonset             7800                None                None
# sunrise             7800                None                None
# sunset              7800                None                None
# DewPointC           7800   22.08076923076923  3.7785730755226186
# ...

# %%
pune.describe().toPandas().transpose()
# Out:
#                        0                   1                   2  \
# summary            count                mean              stddev
# date_time           7800                None                None
# maxtempC            7800   31.21128205128205    4.65410582285364
# mintempC            7800   21.70974358974359   2.805094450671273
# totalSnow_cm        7800                 0.0                 0.0
# sunHour             7800  10.097025641025736  2.2686005384342063
# uvIndex             7800   6.553846153846154  1.0353035272001556
# moon_illumination   7800   46.07282051282051    31.2302901309429
# moonrise            7800                None                None
# moonset             7800                None                None
# sunrise             7800                None                None
# sunset              7800                None                None
# DewPointC           7800  14.947948717948718   6.276474812033953
# ...

# %%
rajasthan.describe().toPandas().transpose()
# Out:
#                        0                    1                   2  \
# summary            count                 mean              stddev
# date_time           7800                 None                None
# maxtempC            7800    33.81846153846154    5.98796653641652
# mintempC            7800   22.837948717948716   6.545912956207546
# totalSnow_cm        7800                  0.0                 0.0
# sunHour             7800   10.925230769231145  2.0273446290609076
# uvIndex             7800    7.150769230769231   1.306806791705247
# moon_illumination   7800    46.07282051282051    31.2302901309429
# moonrise            7800                 None                None
# moonset             7800                 None                None
# sunrise             7800                 None                None
# sunset              7800                 None                None
# DewPointC           7800   10.642307692307693   9.262550967450078
# ...

# %%
shillong.describe().toPandas().transpose()
# Out:
#                        0                   1                   2  \
# summary            count                mean              stddev
# date_time           7800                None                None
# maxtempC            7800   21.90051282051282  3.2560279338447637
# mintempC            7800   13.35897435897436   4.201900176995161
# totalSnow_cm        7800                 0.0                 0.0
# sunHour             7800   9.317846153845927  2.1232275839330255
# uvIndex             7800   4.665641025641025  0.7380272108662033
# moon_illumination   7800   46.07282051282051    31.2302901309429
# moonrise            7800                None                None
# moonset             7800                None                None
# sunrise             7800                None                None
# sunset              7800                None                None
# DewPointC           7800  14.912820512820513   5.423714956306431
# ...

# %%
uttarakhand.describe().toPandas().transpose()
# Out:
#                        0                   1                   2  \
# summary            count                mean              stddev
# date_time           7800                None                None
# maxtempC            7800  29.335384615384616   6.991235458290221
# mintempC            7800  18.155897435897437   6.269766064057416
# totalSnow_cm        7800                 0.0                 0.0
# sunHour             7800    10.7929230769228  2.4785043136960914
# uvIndex             7800   6.118974358974359   1.466363984714446
# moon_illumination   7800   46.07282051282051    31.2302901309429
# moonrise            7800                None                None
# moonset             7800                None                None
# sunrise             7800                None                None
# sunset              7800                None                None
# DewPointC           7800  10.671153846153846   8.370212524283799
# ...

# %%
vellore.describe().toPandas().transpose()
# Out:
#                        0                    1                   2  \
# summary            count                 mean              stddev
# date_time           7800                 None                None
# maxtempC            7800    33.92820512820513  3.9895972381695235
# mintempC            7800   23.745641025641024   3.537126587329125
# totalSnow_cm        7800                  0.0                 0.0
# sunHour             7800    10.64164102564083    2.39064067578805
# uvIndex             7800    7.024615384615385  1.0275892740473596
# moon_illumination   7800    46.07282051282051    31.2302901309429
# moonrise            7800                 None                None
# moonset             7800                 None                None
# sunrise             7800                 None                None
# sunset              7800                 None                None
# DewPointC           7800    19.36602564102564   3.046883239209784
# ...

# %%
# Finding correlation between independent variables and target variable.

# %%
import six

inputColsMysore = []

for i in mysore.columns:
    if not( isinstance(mysore.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, mysore.stat.corr('precipMM',i))
        if ((mysore.stat.corr('precipMM',i) >= 0.20) or (mysore.stat.corr('precipMM',i) <= -0.20)):
            if (mysore.stat.corr('precipMM',i) < 1.0):
                inputColsMysore.append(i)

print(inputColsMysore)
# Out:
# Correlation to precipMM for  maxtempC -0.01607769689567795
# Correlation to precipMM for  mintempC 0.07714870054625808
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.1756055951163433
# Correlation to precipMM for  uvIndex -0.049160553606357356
# Correlation to precipMM for  moon_illumination 0.05518084147574715
# Correlation to precipMM for  DewPointC 0.22481603390491134
# Correlation to precipMM for  FeelsLikeC -0.020584591254227267
# Correlation to precipMM for  HeatIndexC -0.021906210015213538
# Correlation to precipMM for  WindChillC -0.07061535172058339
# Correlation to precipMM for  WindGustKmph 0.17349198016468656
# Correlation to precipMM for  cloudcover 0.31099796588231865
# Correlation to precipMM for  humidity 0.2012036093741773
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.1444188032808859
# Correlation to precipMM for  tempC -0.06158647020751782
# ...

# %%
import six

inputColsBangalore = []

for i in bangalore.columns:
    if not( isinstance(bangalore.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, bangalore.stat.corr('precipMM',i))
        if ((bangalore.stat.corr('precipMM',i) >= 0.20) or (bangalore.stat.corr('precipMM',i) <= -0.20)):
            if (bangalore.stat.corr('precipMM',i) < 1.0):
                inputColsBangalore.append(i)

print(inputColsBangalore)
# Out:
# Correlation to precipMM for  maxtempC -0.1300060081082575
# Correlation to precipMM for  mintempC 0.05247315791973505
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.2165543869043885
# Correlation to precipMM for  uvIndex -0.17171795794055864
# Correlation to precipMM for  moon_illumination 0.04758861831671448
# Correlation to precipMM for  DewPointC 0.26097066495892873
# Correlation to precipMM for  FeelsLikeC -0.008929008509058792
# Correlation to precipMM for  HeatIndexC -0.0060607408632806946
# Correlation to precipMM for  WindChillC -0.07479708963777183
# Correlation to precipMM for  WindGustKmph 0.1844616542412295
# Correlation to precipMM for  cloudcover 0.35937657743346774
# Correlation to precipMM for  humidity 0.22797206711774617
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.17725329079287386
# Correlation to precipMM for  tempC -0.0772252180076496
# ...

# %%
import six

inputColsBhopal = []

for i in bhopal.columns:
    if not( isinstance(bhopal.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, bhopal.stat.corr('precipMM',i))
        if ((bhopal.stat.corr('precipMM',i) >= 0.20) or (bhopal.stat.corr('precipMM',i) <= -0.20)):
            if (bhopal.stat.corr('precipMM',i) < 1.0):
                inputColsBhopal.append(i)

print(inputColsBhopal)
# Out:
# Correlation to precipMM for  maxtempC -0.1283629141491546
# Correlation to precipMM for  mintempC 0.03703230167686133
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.1902470786415283
# Correlation to precipMM for  uvIndex -0.1500268056966472
# Correlation to precipMM for  moon_illumination -0.020831311736131737
# Correlation to precipMM for  DewPointC 0.2901535627675045
# Correlation to precipMM for  FeelsLikeC 0.02438980884365808
# Correlation to precipMM for  HeatIndexC 0.022594833273966424
# Correlation to precipMM for  WindChillC -0.0521643514440013
# Correlation to precipMM for  WindGustKmph 0.2889400113635771
# Correlation to precipMM for  cloudcover 0.37729323455232605
# Correlation to precipMM for  humidity 0.31545942168016966
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.24646675822712968
# Correlation to precipMM for  tempC -0.0461704023542166
# ...

# %%
import six

inputColsCherrapunji = []

for i in cherrapunji.columns:
    if not( isinstance(cherrapunji.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, cherrapunji.stat.corr('precipMM',i))
        if ((cherrapunji.stat.corr('precipMM',i) >= 0.20) or (cherrapunji.stat.corr('precipMM',i) <= -0.20)):
            if (cherrapunji.stat.corr('precipMM',i) < 1.0):
                inputColsCherrapunji.append(i)

print(inputColsCherrapunji)
# Out:
# Correlation to precipMM for  maxtempC 0.10745817405357942
# Correlation to precipMM for  mintempC 0.1038571683044428
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.16251680099422436
# Correlation to precipMM for  uvIndex 0.07837360086545257
# Correlation to precipMM for  moon_illumination -0.0443469107614253
# Correlation to precipMM for  DewPointC 0.3189136956960345
# Correlation to precipMM for  FeelsLikeC 0.1599563030069031
# Correlation to precipMM for  HeatIndexC 0.19506319510751996
# Correlation to precipMM for  WindChillC 0.16570208677898296
# Correlation to precipMM for  WindGustKmph 0.25339490704682055
# Correlation to precipMM for  cloudcover 0.3638215965021612
# Correlation to precipMM for  humidity 0.23570747009961573
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.3122364093522042
# Correlation to precipMM for  tempC 0.1754194705786902
# ...

# %%
import six

inputColsGandhinagar = []

for i in gandhinagar.columns:
    if not( isinstance(gandhinagar.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, gandhinagar.stat.corr('precipMM',i))
        if ((gandhinagar.stat.corr('precipMM',i) >= 0.20) or (gandhinagar.stat.corr('precipMM',i) <= -0.20)):
            if (gandhinagar.stat.corr('precipMM',i) < 1.0):
                inputColsGandhinagar.append(i)

print(inputColsGandhinagar)
# Out:
# Correlation to precipMM for  maxtempC -0.1548415393490962
# Correlation to precipMM for  mintempC 0.07263241910061355
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.33222629987780355
# Correlation to precipMM for  uvIndex -0.1635454858788525
# Correlation to precipMM for  moon_illumination -0.025372378557449386
# Correlation to precipMM for  DewPointC 0.29092307194229783
# Correlation to precipMM for  FeelsLikeC 0.04297374057720172
# Correlation to precipMM for  HeatIndexC 0.041606481790537345
# Correlation to precipMM for  WindChillC -0.059756451008794294
# Correlation to precipMM for  WindGustKmph 0.23006717005028737
# Correlation to precipMM for  cloudcover 0.4230745060388771
# Correlation to precipMM for  humidity 0.37953969694228656
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.28128960238342166
# Correlation to precipMM for  tempC -0.041962211679540236
# ...

# %%
import six

inputColsGangtok = []

for i in gangtok.columns:
    if not( isinstance(gangtok.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, gangtok.stat.corr('precipMM',i))
        if ((gangtok.stat.corr('precipMM',i) >= 0.20) or (gangtok.stat.corr('precipMM',i) <= -0.20)):
            if (gangtok.stat.corr('precipMM',i) < 1.0):
                inputColsGangtok.append(i)

print(inputColsGangtok)
# Out:
# Correlation to precipMM for  maxtempC 0.12075468669700892
# Correlation to precipMM for  mintempC 0.08922575418455078
# Correlation to precipMM for  totalSnow_cm -0.011772135778963288
# Correlation to precipMM for  sunHour -0.148758275817288
# Correlation to precipMM for  uvIndex 0.03074496912536453
# Correlation to precipMM for  moon_illumination 0.013122264107387331
# Correlation to precipMM for  DewPointC 0.36289806105161226
# Correlation to precipMM for  FeelsLikeC 0.1466248838652374
# Correlation to precipMM for  HeatIndexC 0.15245523194921068
# Correlation to precipMM for  WindChillC 0.15093227091794434
# Correlation to precipMM for  WindGustKmph -0.2555758185377352
# Correlation to precipMM for  cloudcover 0.45195909244239996
# Correlation to precipMM for  humidity 0.4178590272860945
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.3251562905440138
# Correlation to precipMM for  tempC 0.14112157406112516
# ...

# %%
import six

inputColsKolkata = []

for i in kolkata.columns:
    if not( isinstance(kolkata.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, kolkata.stat.corr('precipMM',i))
        if ((kolkata.stat.corr('precipMM',i) >= 0.20) or (kolkata.stat.corr('precipMM',i) <= -0.20)):
            if (kolkata.stat.corr('precipMM',i) < 1.0):
                inputColsKolkata.append(i)

print(inputColsKolkata)
# Out:
# Correlation to precipMM for  maxtempC -0.06165160053795304
# Correlation to precipMM for  mintempC 0.027724396414385684
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.1185161458177715
# Correlation to precipMM for  uvIndex -0.08829563263809716
# Correlation to precipMM for  moon_illumination -0.03174012628170705
# Correlation to precipMM for  DewPointC 0.133742643099947
# Correlation to precipMM for  FeelsLikeC 0.021874802871250956
# Correlation to precipMM for  HeatIndexC 0.025013121043636795
# Correlation to precipMM for  WindChillC -0.031959535691681466
# Correlation to precipMM for  WindGustKmph 0.3535887921872812
# Correlation to precipMM for  cloudcover 0.3036741841625478
# Correlation to precipMM for  humidity 0.17395955683104994
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.16408500811046892
# Correlation to precipMM for  tempC -0.008213429911784602
# ...

# %%
import six

inputColsMawsynram = []

for i in mawsynram.columns:
    if not( isinstance(mawsynram.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, mawsynram.stat.corr('precipMM',i))
        if ((mawsynram.stat.corr('precipMM',i) >= 0.20) or (mawsynram.stat.corr('precipMM',i) <= -0.20)):
            if (mawsynram.stat.corr('precipMM',i) < 1.0):
                inputColsMawsynram.append(i)

print(inputColsMawsynram)
# Out:
# Correlation to precipMM for  maxtempC 0.10745817405357942
# Correlation to precipMM for  mintempC 0.1038571683044428
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.15988465325911164
# Correlation to precipMM for  uvIndex 0.07837360086545257
# Correlation to precipMM for  moon_illumination -0.0443469107614253
# Correlation to precipMM for  DewPointC 0.3189136956960345
# Correlation to precipMM for  FeelsLikeC 0.1599563030069031
# Correlation to precipMM for  HeatIndexC 0.19506319510751996
# Correlation to precipMM for  WindChillC 0.16570208677898296
# Correlation to precipMM for  WindGustKmph 0.25339490704682055
# Correlation to precipMM for  cloudcover 0.3638215965021612
# Correlation to precipMM for  humidity 0.23570747009961573
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.3122364093522042
# Correlation to precipMM for  tempC 0.1754194705786902
# ...

# %%
import six

inputColsMeerut = []

for i in meerut.columns:
    if not( isinstance(meerut.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, meerut.stat.corr('precipMM',i))
        if (meerut.stat.corr('precipMM',i) >= 0.15):
            if (meerut.stat.corr('precipMM',i) < 1.0):
                inputColsMeerut.append(i)

print(inputColsMeerut)
# Out:
# Correlation to precipMM for  maxtempC -0.08213272904389964
# Correlation to precipMM for  mintempC -0.0025104880412144233
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.13762070318815856
# Correlation to precipMM for  uvIndex -0.10222069752771139
# Correlation to precipMM for  moon_illumination 0.05334712864107099
# Correlation to precipMM for  DewPointC 0.18205839434373822
# Correlation to precipMM for  FeelsLikeC -0.017419003751174614
# Correlation to precipMM for  HeatIndexC -0.01758128951257452
# Correlation to precipMM for  WindChillC -0.06172932985373949
# Correlation to precipMM for  WindGustKmph 0.20670247111075385
# Correlation to precipMM for  cloudcover 0.3950500738799007
# Correlation to precipMM for  humidity 0.27774679331353785
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.05847445186488942
# Correlation to precipMM for  tempC -0.05016837737495561
# ...

# %%
import six

inputColsMizoram = []

for i in mizoram.columns:
    if not( isinstance(mizoram.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, mizoram.stat.corr('precipMM',i))
        if ((mizoram.stat.corr('precipMM',i) >= 0.20) or (mizoram.stat.corr('precipMM',i) <= -0.20)):
            if (mizoram.stat.corr('precipMM',i) < 1.0):
                inputColsMizoram.append(i)

print(inputColsMizoram)
# Out:
# Correlation to precipMM for  maxtempC -0.056341582978574674
# Correlation to precipMM for  mintempC 0.25575007444191533
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.27699368062342156
# Correlation to precipMM for  uvIndex -0.05694410312528738
# Correlation to precipMM for  moon_illumination -0.02549689379915599
# Correlation to precipMM for  DewPointC 0.348500252842422
# Correlation to precipMM for  FeelsLikeC 0.15644852064763903
# Correlation to precipMM for  HeatIndexC 0.1576378130954064
# Correlation to precipMM for  WindChillC 0.07426994687878719
# Correlation to precipMM for  WindGustKmph 0.11327354436526454
# Correlation to precipMM for  cloudcover 0.350313906426144
# Correlation to precipMM for  humidity 0.29935084855580774
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.29323280091310155
# Correlation to precipMM for  tempC 0.07950756620578815
# ...

# %%
import six

inputColsMumbai = []

for i in mumbai.columns:
    if not( isinstance(mumbai.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, mumbai.stat.corr('precipMM',i))
        if ((mumbai.stat.corr('precipMM',i) >= 0.20) or (mumbai.stat.corr('precipMM',i) <= -0.20)):
            if (mumbai.stat.corr('precipMM',i) < 1.0):
                inputColsMumbai.append(i)

print(inputColsMumbai)
# Out:
# Correlation to precipMM for  maxtempC -0.22065489039858574
# Correlation to precipMM for  mintempC -0.09500172981452241
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.37730707104997924
# Correlation to precipMM for  uvIndex -0.24820489491714925
# Correlation to precipMM for  moon_illumination 0.03147601601024063
# Correlation to precipMM for  DewPointC 0.14486129737214834
# Correlation to precipMM for  FeelsLikeC -0.057469888107778845
# Correlation to precipMM for  HeatIndexC -0.05763137567372977
# Correlation to precipMM for  WindChillC -0.129728879331104
# Correlation to precipMM for  WindGustKmph 0.45262790596811076
# Correlation to precipMM for  cloudcover 0.35921403169438265
# Correlation to precipMM for  humidity 0.27448812196024636
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.33650004181453796
# Correlation to precipMM for  tempC -0.08656925467139714
# ...

# %%
import six

inputColsPune = []

for i in pune.columns:
    if not( isinstance(pune.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, pune.stat.corr('precipMM',i))
        if ((pune.stat.corr('precipMM',i) >= 0.20) or (pune.stat.corr('precipMM',i) <= -0.20)):
            if (pune.stat.corr('precipMM',i) < 1.0):
                inputColsPune.append(i)

print(inputColsPune)
# Out:
# Correlation to precipMM for  maxtempC -0.20972694546991463
# Correlation to precipMM for  mintempC 0.0074223924280988575
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.24147941009265225
# Correlation to precipMM for  uvIndex -0.20100874084839374
# Correlation to precipMM for  moon_illumination -0.007757903447165096
# Correlation to precipMM for  DewPointC 0.23674042420989067
# Correlation to precipMM for  FeelsLikeC -0.04652828837166049
# Correlation to precipMM for  HeatIndexC -0.04340396132301617
# Correlation to precipMM for  WindChillC -0.10140731996155662
# Correlation to precipMM for  WindGustKmph 0.17944885606865446
# Correlation to precipMM for  cloudcover 0.32618797875672945
# Correlation to precipMM for  humidity 0.25381249184520577
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.25407402736203416
# Correlation to precipMM for  tempC -0.0835603570337392
# ...

# %%
import six

inputColsRajasthan = []

for i in rajasthan.columns:
    if not( isinstance(rajasthan.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, rajasthan.stat.corr('precipMM',i))
        if ((rajasthan.stat.corr('precipMM',i) >= 0.20) or (rajasthan.stat.corr('precipMM',i) <= -0.20)):
            if (rajasthan.stat.corr('precipMM',i) < 1.0):
                inputColsRajasthan.append(i)

print(inputColsRajasthan)
# Out:
# Correlation to precipMM for  maxtempC -0.013761444768144636
# Correlation to precipMM for  mintempC 0.07889638991810408
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.1920797446805144
# Correlation to precipMM for  uvIndex -0.032505922580257404
# Correlation to precipMM for  moon_illumination 0.008354603218267939
# Correlation to precipMM for  DewPointC 0.21350529760732567
# Correlation to precipMM for  FeelsLikeC 0.06466730986049057
# Correlation to precipMM for  HeatIndexC 0.06621983079525162
# Correlation to precipMM for  WindChillC 0.008660437750360146
# Correlation to precipMM for  WindGustKmph 0.20493203403298924
# Correlation to precipMM for  cloudcover 0.30933089435210825
# Correlation to precipMM for  humidity 0.263634385860556
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.18199905434299454
# Correlation to precipMM for  tempC 0.011795054172350548
# ...

# %%
import six

inputColsShillong = []

for i in shillong.columns:
    if not( isinstance(shillong.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, shillong.stat.corr('precipMM',i))
        if ((shillong.stat.corr('precipMM',i) >= 0.20) or (shillong.stat.corr('precipMM',i) <= -0.20)):
            if (shillong.stat.corr('precipMM',i) < 1.0):
                inputColsShillong.append(i)

print(inputColsShillong)
# Out:
# Correlation to precipMM for  maxtempC 0.10745817405357942
# Correlation to precipMM for  mintempC 0.1038571683044428
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.16182750688249656
# Correlation to precipMM for  uvIndex 0.07837360086545257
# Correlation to precipMM for  moon_illumination -0.0443469107614253
# Correlation to precipMM for  DewPointC 0.3189136956960345
# Correlation to precipMM for  FeelsLikeC 0.1599563030069031
# Correlation to precipMM for  HeatIndexC 0.19506319510751996
# Correlation to precipMM for  WindChillC 0.16570208677898296
# Correlation to precipMM for  WindGustKmph 0.25339490704682055
# Correlation to precipMM for  cloudcover 0.3638215965021612
# Correlation to precipMM for  humidity 0.23570747009961573
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.3122364093522042
# Correlation to precipMM for  tempC 0.1754194705786902
# ...

# %%
import six

inputColsUttarakhand = []

for i in uttarakhand.columns:
    if not( isinstance(uttarakhand.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, uttarakhand.stat.corr('precipMM',i))
        if ((uttarakhand.stat.corr('precipMM',i) >= 0.20) or (uttarakhand.stat.corr('precipMM',i) <= -0.20)):
            if (uttarakhand.stat.corr('precipMM',i) < 1.0):
                inputColsUttarakhand.append(i)

print(inputColsUttarakhand)
# Out:
# Correlation to precipMM for  maxtempC -0.04250818510176076
# Correlation to precipMM for  mintempC 0.08265934322749574
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.15760969335900674
# Correlation to precipMM for  uvIndex -0.08950018151522192
# Correlation to precipMM for  moon_illumination 0.04564733305696101
# Correlation to precipMM for  DewPointC 0.2943007744091961
# Correlation to precipMM for  FeelsLikeC 0.057007491052690686
# Correlation to precipMM for  HeatIndexC 0.06084163305715229
# Correlation to precipMM for  WindChillC 0.002418511265692908
# Correlation to precipMM for  WindGustKmph -0.054727664312261975
# Correlation to precipMM for  cloudcover 0.43522810271827966
# Correlation to precipMM for  humidity 0.34652237534709046
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.19571899331751308
# Correlation to precipMM for  tempC 0.015008160841966312
# ...

# %%
import six

inputColsVellore = []

for i in vellore.columns:
    if not( isinstance(vellore.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to precipMM for ", i, vellore.stat.corr('precipMM',i))
        if ((vellore.stat.corr('precipMM',i) >= 0.20) or (vellore.stat.corr('precipMM',i) <= -0.20)):
            if (vellore.stat.corr('precipMM',i) < 1.0):
                inputColsVellore.append(i)

print(inputColsVellore)
# Out:
# Correlation to precipMM for  maxtempC -0.14288293158151344
# Correlation to precipMM for  mintempC 0.038816059355381224
# Correlation to precipMM for  totalSnow_cm nan
# Correlation to precipMM for  sunHour -0.25476162506407246
# Correlation to precipMM for  uvIndex -0.15605990217176302
# Correlation to precipMM for  moon_illumination 0.010561527284616321
# Correlation to precipMM for  DewPointC 0.25946020396396036
# Correlation to precipMM for  FeelsLikeC -0.036489803393550305
# Correlation to precipMM for  HeatIndexC -0.03976654621404005
# Correlation to precipMM for  WindChillC -0.09317448230165262
# Correlation to precipMM for  WindGustKmph 0.048811081354956286
# Correlation to precipMM for  cloudcover 0.3901634849298894
# Correlation to precipMM for  humidity 0.2112377984353211
# Correlation to precipMM for  precipMM 1.0
# Correlation to precipMM for  pressure -0.11184456888206346
# Correlation to precipMM for  tempC -0.08119907923675558
# ...

# %%
from pyspark.ml.feature import VectorAssembler

vectorAssembler = VectorAssembler(inputCols = inputColsMysore, outputCol = 'features')
mysore_df = vectorAssembler.transform(mysore)
mysore_df = mysore_df.select(['features', 'precipMM'])
mysore_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# |[18.0,24.0,90.0,1...|     0.0|
# |[17.0,46.0,95.0,2.0]|     0.0|
# |[18.0,5.0,79.0,10.0]|     0.0|
# |[16.0,14.0,51.0,1...|     0.0|
# |[16.0,31.0,46.0,1...|     0.0|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsBangalore, outputCol = 'features')
bangalore_df = vectorAssembler.transform(bangalore)
bangalore_df = bangalore_df.select(['features', 'precipMM'])
bangalore_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# |[11.6,17.0,28.0,8...|     0.0|
# |[11.6,17.0,42.0,9...|     0.0|
# |[11.6,17.0,20.0,7...|     0.0|
# |[11.6,16.0,59.0,5...|     0.0|
# |[11.6,16.0,46.0,5...|     0.0|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsBhopal, outputCol = 'features')
bhopal_df = vectorAssembler.transform(bhopal)
bhopal_df = bhopal_df.select(['features', 'precipMM'])
bhopal_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# |[0.0,8.0,0.0,31.0...|     0.0|
# |[-3.0,8.0,0.0,28....|     0.0|
# |[1.0,5.0,0.0,30.0...|     0.0|
# |[2.0,7.0,0.0,22.0...|     0.0|
# |[2.0,8.0,0.0,20.0...|     0.0|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsCherrapunji, outputCol = 'features')
cherrapunji_df = vectorAssembler.transform(cherrapunji)
cherrapunji_df = cherrapunji_df.select(['features', 'precipMM'])
cherrapunji_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# |[9.0,3.0,54.0,94....|     0.0|
# |[7.0,1.0,60.0,96....|     0.0|
# |[9.0,1.0,66.0,76....|     0.0|
# |[9.0,5.0,98.0,76....|     0.0|
# |[9.0,4.0,90.0,77....|     0.1|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsGandhinagar, outputCol = 'features')
gandhinagar_df = vectorAssembler.transform(gandhinagar)
gandhinagar_df = gandhinagar_df.select(['features', 'precipMM'])
gandhinagar_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# |[10.9,4.0,27.0,0....|     0.0|
# |[10.9,3.0,33.0,2....|     0.0|
# |[10.9,4.0,28.0,2....|     0.0|
# |[10.9,5.0,17.0,3....|     0.0|
# |[10.9,6.0,13.0,4....|     0.0|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsGangtok, outputCol = 'features')
gangtok_df = vectorAssembler.transform(gangtok)
gangtok_df = gangtok_df.select(['features', 'precipMM'])
gangtok_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# |[-1.0,6.0,0.0,50....|     0.0|
# |[-5.0,7.0,0.0,41....|     0.0|
# |[-2.0,6.0,0.0,32....|     0.0|
# |[1.0,14.0,0.0,35....|     0.0|
# |[3.0,14.0,4.0,46....|     0.0|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsKolkata, outputCol = 'features')
kolkata_df = vectorAssembler.transform(kolkata)
kolkata_df = kolkata_df.select(['features', 'precipMM'])
kolkata_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# | [10.0,0.0,10.0,9.0]|     0.0|
# |  [7.0,0.0,10.0,6.0]|     0.0|
# |[13.0,0.0,10.0,11.0]|     0.0|
# |[11.0,0.0,10.0,10.0]|     0.0|
# |[14.0,0.0,10.0,12.0]|     0.0|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsMawsynram, outputCol = 'features')
mawsynram_df = vectorAssembler.transform(mawsynram)
mawsynram_df = mawsynram_df.select(['features', 'precipMM'])
mawsynram_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# |[9.0,3.0,54.0,94....|     0.0|
# |[7.0,1.0,60.0,96....|     0.0|
# |[9.0,1.0,66.0,76....|     0.0|
# |[9.0,5.0,98.0,76....|     0.0|
# |[9.0,4.0,90.0,77....|     0.1|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsMeerut, outputCol = 'features')
meerut_df = vectorAssembler.transform(meerut)
meerut_df = meerut_df.select(['features', 'precipMM'])
meerut_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# |[-2.0,23.0,0.0,39.0]|     0.0|
# |[-2.0,26.0,1.0,43.0]|     0.0|
# |[-3.0,33.0,2.0,39.0]|     0.0|
# | [1.0,15.0,3.0,29.0]|     0.0|
# | [1.0,22.0,2.0,25.0]|     0.0|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsMizoram, outputCol = 'features')
mizoram_df = vectorAssembler.transform(mizoram)
mizoram_df = mizoram_df.select(['features', 'precipMM'])
mizoram_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# |[7.0,8.7,4.0,0.0,...|     0.0|
# |[7.0,8.7,2.0,0.0,...|     0.0|
# |[7.0,8.7,5.0,0.0,...|     0.0|
# |[7.0,8.7,5.0,0.0,...|     0.0|
# |[7.0,8.7,5.0,0.0,...|     0.0|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsMumbai, outputCol = 'features')
mumbai_df = vectorAssembler.transform(mumbai)
mumbai_df = mumbai_df.select(['features', 'precipMM'])
mumbai_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# |[31.0,11.1,7.0,7....|     0.0|
# |[31.0,11.1,7.0,9....|     0.0|
# |[31.0,11.1,7.0,12...|     0.0|
# |[31.0,11.1,7.0,5....|     0.0|
# |[31.0,11.1,7.0,10...|     0.0|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsPune, outputCol = 'features')
pune_df = vectorAssembler.transform(pune)
pune_df = pune_df.select(['features', 'precipMM'])
pune_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# |[30.0,11.1,6.0,8....|     0.0|
# |[30.0,11.1,6.0,8....|     0.0|
# |[30.0,11.1,6.0,8....|     0.0|
# |[30.0,11.1,6.0,10...|     0.0|
# |[30.0,11.1,6.0,12...|     0.0|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsRajasthan, outputCol = 'features')
rajasthan_df = vectorAssembler.transform(rajasthan)
rajasthan_df = rajasthan_df.select(['features', 'precipMM'])
rajasthan_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# |[-4.0,20.0,1.0,26...|     0.0|
# |[-6.0,17.0,0.0,24...|     0.0|
# |[-4.0,15.0,2.0,24...|     0.0|
# |[-2.0,6.0,4.0,18....|     0.0|
# |[-2.0,11.0,3.0,16...|     0.0|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsShillong, outputCol = 'features')
shillong_df = vectorAssembler.transform(shillong)
shillong_df = shillong_df.select(['features', 'precipMM'])
shillong_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# |[9.0,3.0,54.0,94....|     0.0|
# |[7.0,1.0,60.0,96....|     0.0|
# |[9.0,1.0,66.0,76....|     0.0|
# |[9.0,5.0,98.0,76....|     0.0|
# |[9.0,4.0,90.0,77....|     0.1|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsUttarakhand, outputCol = 'features')
uttarakhand_df = vectorAssembler.transform(uttarakhand)
uttarakhand_df = uttarakhand_df.select(['features', 'precipMM'])
uttarakhand_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# | [2.0,1.0,47.0,10.0]|     0.0|
# | [0.0,2.0,45.0,10.0]|     0.0|
# | [0.0,3.0,44.0,10.0]|     0.0|
# | [3.0,3.0,31.0,10.0]|     0.0|
# |[2.0,16.0,28.0,10.0]|     0.0|
# +--------------------+--------+
# only showing top 5 rows

# %%
vectorAssembler = VectorAssembler(inputCols = inputColsVellore, outputCol = 'features')
vellore_df = vectorAssembler.transform(vellore)
vellore_df = vellore_df.select(['features', 'precipMM'])
vellore_df.show(5)
# Out:
# +--------------------+--------+
# |            features|precipMM|
# +--------------------+--------+
# |[11.6,19.0,44.0,9...|     0.0|
# |[11.6,19.0,46.0,9...|     0.0|
# |[11.6,20.0,23.0,7...|     0.0|
# |[11.6,19.0,34.0,5...|     0.0|
# |[11.6,19.0,57.0,5...|     0.0|
# +--------------------+--------+
# only showing top 5 rows

# %%
# ML - Linear Regression with PySpark and MLlib

# %%
splits = mysore_df.randomSplit([0.7, 0.3])
train_df_mysore = splits[0]
test_df_mysore = splits[1]

# %%
splits = bangalore_df.randomSplit([0.7, 0.3])
train_df_bangalore = splits[0]
test_df_bangalore = splits[1]

# %%
splits = bhopal_df.randomSplit([0.7, 0.3])
train_df_bhopal = splits[0]
test_df_bhopal = splits[1]

# %%
splits = cherrapunji_df.randomSplit([0.7, 0.3])
train_df_cherrapunji = splits[0]
test_df_cherrapunji = splits[1]

# %%
splits = gandhinagar_df.randomSplit([0.7, 0.3])
train_df_gandhinagar = splits[0]
test_df_gandhinagar = splits[1]

# %%
splits = gangtok_df.randomSplit([0.7, 0.3])
train_df_gangtok = splits[0]
test_df_gangtok = splits[1]

# %%
splits = kolkata_df.randomSplit([0.7, 0.3])
train_df_kolkata = splits[0]
test_df_kolkata = splits[1]

# %%
splits = mawsynram_df.randomSplit([0.7, 0.3])
train_df_mawsynram = splits[0]
test_df_mawsynram = splits[1]

# %%
splits = meerut_df.randomSplit([0.7, 0.3])
train_df_meerut = splits[0]
test_df_meerut = splits[1]

# %%
splits = mizoram_df.randomSplit([0.7, 0.3])
train_df_mizoram = splits[0]
test_df_mizoram = splits[1]

# %%
splits = mumbai_df.randomSplit([0.7, 0.3])
train_df_mumbai = splits[0]
test_df_mumbai = splits[1]

# %%
splits = pune_df.randomSplit([0.7, 0.3])
train_df_pune = splits[0]
test_df_pune = splits[1]

# %%
splits = rajasthan_df.randomSplit([0.7, 0.3])
train_df_rajasthan = splits[0]
test_df_rajasthan = splits[1]

# %%
splits = shillong_df.randomSplit([0.7, 0.3])
train_df_shillong = splits[0]
test_df_shillong = splits[1]

# %%
splits = uttarakhand_df.randomSplit([0.7, 0.3])
train_df_uttarakhand = splits[0]
test_df_uttarakhand = splits[1]

# %%
splits = vellore_df.randomSplit([0.7, 0.3])
train_df_vellore = splits[0]
test_df_vellore = splits[1]

# %%
from pyspark.ml.regression import LinearRegression

lr = LinearRegression(featuresCol = 'features', labelCol='precipMM', maxIter=10, regParam=0.3, elasticNetParam=0.8)
lr_model_mysore = lr.fit(train_df_mysore)
print("Coefficients: " + str(lr_model_mysore.coefficients))
print("Intercept: " + str(lr_model_mysore.intercept))
# Out:
# Coefficients: [0.0005738386537878456,0.0105308975719834,0.0,-0.09887045571797795]
# Intercept: 1.1049957535151522

# %%
lr_model_bangalore = lr.fit(train_df_bangalore)
print("Coefficients: " + str(lr_model_bangalore.coefficients))
print("Intercept: " + str(lr_model_bangalore.intercept))
# Out:
# Coefficients: [0.0,0.0,0.006976186971620868,0.0,-0.33304752499252765]
# Intercept: 3.528654881628061

# %%
lr_model_bhopal = lr.fit(train_df_bhopal)
print("Coefficients: " + str(lr_model_bhopal.coefficients))
print("Intercept: " + str(lr_model_bhopal.intercept))
# Out:
# Coefficients: [0.0,0.013612818666614575,0.011447341729501877,0.0,0.0,-0.2981172318397109]
# Intercept: 2.8927168625213944

# %%
lr_model_cherrapunji = lr.fit(train_df_cherrapunji)
print("Coefficients: " + str(lr_model_cherrapunji.coefficients))
print("Intercept: " + str(lr_model_cherrapunji.intercept))
# Out:
# Coefficients: [0.03216845042478113,0.08432281637333158,0.02594163414292941,0.0,-0.051617227936393194,-0.08667041040700532]
# Intercept: 52.079475142901316

# %%
lr_model_gandhinagar = lr.fit(train_df_gandhinagar)
print("Coefficients: " + str(lr_model_gandhinagar.coefficients))
print("Intercept: " + str(lr_model_gandhinagar.intercept))
# Out:
# Coefficients: [0.0,0.0,0.009420839578920108,0.009160807212125258,0.0028113845635453724,0.0,-0.3049378852300534]
# Intercept: 2.9230747443287535

# %%
lr_model_gangtok = lr.fit(train_df_gangtok)
print("Coefficients: " + str(lr_model_gangtok.coefficients))
print("Intercept: " + str(lr_model_gangtok.intercept))
# Out:
# Coefficients: [0.0,0.0,0.011236459301290464,0.006273631789367046,-0.014912574229629792,-0.34312608129252004,0.0]
# Intercept: 18.384891018508224

# %%
lr_model_kolkata = lr.fit(train_df_kolkata)
print("Coefficients: " + str(lr_model_kolkata.coefficients))
print("Intercept: " + str(lr_model_kolkata.intercept))
# Out:
# Coefficients: [0.026377526941272607,0.004926451063923042,-0.20742855610923594,0.0]
# Intercept: 1.8743008304267466

# %%
lr_model_mawsynram = lr.fit(train_df_mawsynram)
print("Coefficients: " + str(lr_model_mawsynram.coefficients))
print("Intercept: " + str(lr_model_mawsynram.intercept))
# Out:
# Coefficients: [0.03555316262615217,0.07984905352398253,0.026653796025227293,0.0,-0.05258220863884317,-0.08387605969615587]
# Intercept: 53.00740731260149

# %%
lr_model_meerut = lr.fit(train_df_meerut)
print("Coefficients: " + str(lr_model_meerut.coefficients))
print("Intercept: " + str(lr_model_meerut.intercept))
# Out:
# Coefficients: [0.0,0.0,0.004233663266047027,0.0]
# Intercept: 0.10076473928470048

# %%
lr_model_mizoram = lr.fit(train_df_mizoram)
print("Coefficients: " + str(lr_model_mizoram.coefficients))
print("Intercept: " + str(lr_model_mizoram.intercept))
# Out:
# Coefficients: [0.0,-0.10992203565199511,0.03740592619944756,0.005277071673216056,0.0033396780977423546,-0.010524779579323129]
# Intercept: 11.478991189087218

# %%
lr_model_mumbai = lr.fit(train_df_mumbai)
print("Coefficients: " + str(lr_model_mumbai.coefficients))
print("Intercept: " + str(lr_model_mumbai.intercept))
# Out:
# Coefficients: [0.0,-0.09835255575069388,0.0,0.07842696188502458,0.0,0.0,-0.04670066570053554,-0.66493432108433,0.0]
# Intercept: 53.91872427728908

# %%
lr_model_pune = lr.fit(train_df_pune)
print("Coefficients: " + str(lr_model_pune.coefficients))
print("Intercept: " + str(lr_model_pune.intercept))
# Out:
# Coefficients: [0.0,0.0,0.0,0.0,0.007535906063140757,0.0,-0.0053508236906518476,-0.3463413599664247]
# Intercept: 9.048136050290442

# %%
lr_model_rajasthan = lr.fit(train_df_rajasthan)
print("Coefficients: " + str(lr_model_rajasthan.coefficients))
print("Intercept: " + str(lr_model_rajasthan.intercept))
# Out:
# Coefficients: [0.0,0.008423168286470401,0.008037069835161758,0.0,-0.1784880201193728]
# Intercept: 1.732432593805767

# %%
lr_model_shillong = lr.fit(train_df_shillong)
print("Coefficients: " + str(lr_model_shillong.coefficients))
print("Intercept: " + str(lr_model_shillong.intercept))
# Out:
# Coefficients: [0.033920623772868475,0.08154088416683944,0.026542324519051218,0.0,-0.05412856033655245,-0.08600688277434348]
# Intercept: 54.596858487892476

# %%
lr_model_uttarakhand = lr.fit(train_df_uttarakhand)
print("Coefficients: " + str(lr_model_uttarakhand.coefficients))
print("Intercept: " + str(lr_model_uttarakhand.intercept))
# Out:
# Coefficients: [0.0,0.009591418604330357,0.0005000164911347389,-0.2090236764073738]
# Intercept: 2.2018321339242384

# %%
lr_model_vellore = lr.fit(train_df_vellore)
print("Coefficients: " + str(lr_model_vellore.coefficients))
print("Intercept: " + str(lr_model_vellore.intercept))
# Out:
# Coefficients: [0.0,0.0,0.006993324875548645,0.0,-0.07512167143281136]
# Intercept: 0.8488888893109623

# %%
trainingSummary_mysore = lr_model_mysore.summary
print("RMSE: %f" % trainingSummary_mysore.rootMeanSquaredError)
print("r2: %f" % trainingSummary_mysore.r2)
train_df_mysore.describe().show()
# Out:
# RMSE: 1.860930
# r2: 0.108495
# +-------+------------------+
# |summary|          precipMM|
# +-------+------------------+
# |  count|              5403|
# |   mean|0.5422728114010735|
# | stddev| 1.971098322926638|
# |    min|               0.0|
# |    max|              49.7|
# +-------+------------------+

# %%
trainingSummary_bangalore = lr_model_bangalore.summary
print("RMSE: %f" % trainingSummary_bangalore.rootMeanSquaredError)
print("r2: %f" % trainingSummary_bangalore.r2)
train_df_bangalore.describe().show()
# Out:
# RMSE: 1.412823
# r2: 0.298615
# +-------+------------------+
# |summary|          precipMM|
# +-------+------------------+
# |  count|              5455|
# |   mean|0.5217415215398672|
# | stddev|1.6871329453466846|
# |    min|               0.0|
# |    max|              19.9|
# +-------+------------------+

# %%
trainingSummary_bhopal = lr_model_bhopal.summary
print("RMSE: %f" % trainingSummary_bhopal.rootMeanSquaredError)
print("r2: %f" % trainingSummary_bhopal.r2)
train_df_bhopal.describe().show()
# Out:
# RMSE: 1.849756
# r2: 0.246330
# +-------+------------------+
# |summary|          precipMM|
# +-------+------------------+
# |  count|              5463|
# |   mean|0.5258832143510899|
# | stddev| 2.130903719450779|
# |    min|               0.0|
# |    max|              54.9|
# +-------+------------------+

# %%
trainingSummary_cherrapunji = lr_model_cherrapunji.summary
print("RMSE: %f" % trainingSummary_cherrapunji.rootMeanSquaredError)
print("r2: %f" % trainingSummary_cherrapunji.r2)
train_df_cherrapunji.describe().show()
# Out:
# RMSE: 3.902482
# r2: 0.168307
# +-------+------------------+
# |summary|          precipMM|
# +-------+------------------+
# |  count|              5464|
# |   mean|1.6886896046852116|
# | stddev|   4.2795599273529|
# |    min|               0.0|
# |    max|              59.2|
# +-------+------------------+

# %%
trainingSummary_gandhinagar = lr_model_gandhinagar.summary
print("RMSE: %f" % trainingSummary_gandhinagar.rootMeanSquaredError)
print("r2: %f" % trainingSummary_gandhinagar.r2)
train_df_gandhinagar.describe().show()
# Out:
# RMSE: 1.490462
# r2: 0.306359
# +-------+------------------+
# |summary|          precipMM|
# +-------+------------------+
# |  count|              5386|
# |   mean|0.4266617155588546|
# | stddev|1.7897568540423625|
# |    min|               0.0|
# |    max|              29.1|
# +-------+------------------+

# %%
trainingSummary_gangtok = lr_model_gangtok.summary
print("RMSE: %f" % trainingSummary_gangtok.rootMeanSquaredError)
print("r2: %f" % trainingSummary_gangtok.r2)
train_df_gangtok.describe().show()
# Out:
# RMSE: 1.765132
# r2: 0.295408
# +-------+------------------+
# |summary|          precipMM|
# +-------+------------------+
# |  count|              5375|
# |   mean|0.8785860465116292|
# | stddev| 2.103046209549399|
# |    min|               0.0|
# |    max|              47.5|
# +-------+------------------+

# %%
trainingSummary_kolkata = lr_model_kolkata.summary
print("RMSE: %f" % trainingSummary_kolkata.rootMeanSquaredError)
print("r2: %f" % trainingSummary_kolkata.r2)
train_df_kolkata.describe().show()
# Out:
# RMSE: 1.548870
# r2: 0.211739
# +-------+------------------+
# |summary|          precipMM|
# +-------+------------------+
# |  count|              5460|
# |   mean|0.3913553113553112|
# | stddev|1.7446955680434302|
# |    min|               0.0|
# |    max|              52.9|
# +-------+------------------+

# %%
trainingSummary_mawsynram = lr_model_mawsynram.summary
print("RMSE: %f" % trainingSummary_mawsynram.rootMeanSquaredError)
print("r2: %f" % trainingSummary_mawsynram.r2)
train_df_mawsynram.describe().show()
# Out:
# RMSE: 3.912522
# r2: 0.170020
# +-------+------------------+
# |summary|          precipMM|
# +-------+------------------+
# |  count|              5460|
# |   mean|1.7410622710622696|
# | stddev|  4.29499668102141|
# |    min|               0.0|
# |    max|              76.6|
# +-------+------------------+

# %%
trainingSummary_meerut = lr_model_meerut.summary
print("RMSE: %f" % trainingSummary_meerut.rootMeanSquaredError)
print("r2: %f" % trainingSummary_meerut.r2)
train_df_meerut.describe().show()
# Out:
# RMSE: 0.864407
# r2: 0.080336
# +-------+-------------------+
# |summary|           precipMM|
# +-------+-------------------+
# |  count|               5512|
# |   mean|0.18695573294629939|
# | stddev| 0.9014526993629138|
# |    min|                0.0|
# |    max|               15.7|
# +-------+-------------------+

# %%
trainingSummary_mizoram = lr_model_mizoram.summary
print("RMSE: %f" % trainingSummary_mizoram.rootMeanSquaredError)
print("r2: %f" % trainingSummary_mizoram.r2)
train_df_mizoram.describe().show()
# Out:
# RMSE: 1.857174
# r2: 0.172837
# +-------+------------------+
# |summary|          precipMM|
# +-------+------------------+
# |  count|              5405|
# |   mean|0.8049213691026814|
# | stddev| 2.042195932970703|
# |    min|               0.0|
# |    max|              29.2|
# +-------+------------------+

# %%
trainingSummary_mumbai = lr_model_mumbai.summary
print("RMSE: %f" % trainingSummary_mumbai.rootMeanSquaredError)
print("r2: %f" % trainingSummary_mumbai.r2)
train_df_mumbai.describe().show()
# Out:
# RMSE: 3.940341
# r2: 0.274262
# +-------+------------------+
# |summary|          precipMM|
# +-------+------------------+
# |  count|              5410|
# |   mean|0.9946210720887313|
# | stddev| 4.625768681870007|
# |    min|               0.0|
# |    max|             134.5|
# +-------+------------------+

# %%
trainingSummary_pune = lr_model_pune.summary
print("RMSE: %f" % trainingSummary_pune.rootMeanSquaredError)
print("r2: %f" % trainingSummary_pune.r2)
train_df_pune.describe().show()
# Out:
# RMSE: 1.933286
# r2: 0.194158
# +-------+------------------+
# |summary|          precipMM|
# +-------+------------------+
# |  count|              5430|
# |   mean|0.4754327808471417|
# | stddev|2.1538283064643724|
# |    min|               0.0|
# |    max|              44.7|
# +-------+------------------+

# %%
trainingSummary_rajasthan = lr_model_rajasthan.summary
print("RMSE: %f" % trainingSummary_rajasthan.rootMeanSquaredError)
print("r2: %f" % trainingSummary_rajasthan.r2)
train_df_rajasthan.describe().show()
# Out:
# RMSE: 1.530872
# r2: 0.156375
# +-------+-------------------+
# |summary|           precipMM|
# +-------+-------------------+
# |  count|               5396|
# |   mean|0.25871015567086736|
# | stddev| 1.6668807128796166|
# |    min|                0.0|
# |    max|               43.3|
# +-------+-------------------+

# %%
trainingSummary_shillong = lr_model_shillong.summary
print("RMSE: %f" % trainingSummary_shillong.rootMeanSquaredError)
print("r2: %f" % trainingSummary_shillong.r2)
train_df_shillong.describe().show()
# Out:
# RMSE: 4.003770
# r2: 0.165021
# +-------+------------------+
# |summary|          precipMM|
# +-------+------------------+
# |  count|              5552|
# |   mean|1.7222982708933725|
# | stddev|  4.38198107561089|
# |    min|               0.0|
# |    max|              76.6|
# +-------+------------------+

# %%
trainingSummary_uttarakhand = lr_model_uttarakhand.summary
print("RMSE: %f" % trainingSummary_uttarakhand.rootMeanSquaredError)
print("r2: %f" % trainingSummary_uttarakhand.r2)
train_df_uttarakhand.describe().show()
# Out:
# RMSE: 1.304030
# r2: 0.244044
# +-------+-------------------+
# |summary|           precipMM|
# +-------+-------------------+
# |  count|               5443|
# |   mean|0.40431747198236195|
# | stddev|  1.499958871138236|
# |    min|                0.0|
# |    max|               45.5|
# +-------+-------------------+

# %%
trainingSummary_vellore = lr_model_vellore.summary
print("RMSE: %f" % trainingSummary_vellore.rootMeanSquaredError)
print("r2: %f" % trainingSummary_vellore.r2)
train_df_vellore.describe().show()
# Out:
# RMSE: 1.120193
# r2: 0.158961
# +-------+------------------+
# |summary|          precipMM|
# +-------+------------------+
# |  count|              5535|
# |   mean|0.3420596205962036|
# | stddev|1.2215855048681081|
# |    min|               0.0|
# |    max|              28.2|
# +-------+------------------+

# %%
lr_predictions_mysore = lr_model_mysore.transform(test_df_mysore)
lr_predictions_mysore.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_mysore = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_mysore.evaluate(lr_predictions_mysore))

test_result_mysore = lr_model_mysore.evaluate(test_df_mysore)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_mysore.rootMeanSquaredError)
# Out:
# +-------------------+--------+-------------------+
# |         prediction|precipMM|           features|
# +-------------------+--------+-------------------+
# |0.11629119633537277|     0.0|[0.0,0.0,12.0,10.0]|
# |0.11686503498916057|     0.0|[1.0,0.0,11.0,10.0]|
# |0.11686503498916057|     0.0|[1.0,0.0,11.0,10.0]|
# |0.11686503498916057|     0.0|[1.0,0.0,13.0,10.0]|
# |-0.8718395221906188|     0.0|[1.0,0.0,13.0,20.0]|
# +-------------------+--------+-------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.123608
# Root Mean Squared Error (RMSE) on test data = 1.72524

# %%
lr_predictions_bangalore = lr_model_bangalore.transform(test_df_bangalore)
lr_predictions_bangalore.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_bangalore = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_bangalore.evaluate(lr_predictions_bangalore))

test_result_bangalore = lr_model_bangalore.evaluate(test_df_bangalore)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_bangalore.rootMeanSquaredError)
# Out:
# +-------------------+--------+--------------------+
# |         prediction|precipMM|            features|
# +-------------------+--------+--------------------+
# | 0.4493223626811358|     0.0|[4.2,16.0,36.0,78...|
# | 0.4493223626811358|     0.0|[4.2,16.0,36.0,92...|
# | 0.4562985496527565|     0.0|[4.2,16.0,37.0,86...|
# | 0.4702509235959984|     0.0|[4.2,16.0,39.0,89...|
# |0.47722711056761913|     0.0|[4.2,16.0,40.0,90...|
# +-------------------+--------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.270141
# Root Mean Squared Error (RMSE) on test data = 1.50183

# %%
lr_predictions_bhopal = lr_model_bhopal.transform(test_df_bhopal)
lr_predictions_bhopal.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_bhopal = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_bhopal.evaluate(lr_predictions_bhopal))

test_result_bhopal = lr_model_bhopal.evaluate(test_df_bhopal)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_bhopal.rootMeanSquaredError)
# Out:
# +-------------------+--------+--------------------+
# |         prediction|precipMM|            features|
# +-------------------+--------+--------------------+
# | 0.1293496427901184|     0.0|[-11.0,16.0,0.0,4...|
# |0.18380091745657667|     0.0|[-10.0,20.0,0.0,4...|
# |0.03405991212381654|     0.0|[-9.0,9.0,0.0,5.0...|
# |0.04767273079043122|     0.0|[-9.0,10.0,0.0,4....|
# |0.08851118679027481|     0.0|[-9.0,13.0,0.0,4....|
# +-------------------+--------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.185146
# Root Mean Squared Error (RMSE) on test data = 2.60137

# %%
lr_predictions_cherrapunji = lr_model_cherrapunji.transform(test_df_cherrapunji)
lr_predictions_cherrapunji.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_cherrapunji = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_cherrapunji.evaluate(lr_predictions_cherrapunji))

test_result_cherrapunji = lr_model_cherrapunji.evaluate(test_df_cherrapunji)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_cherrapunji.rootMeanSquaredError)
# Out:
# +-------------------+--------+--------------------+
# |         prediction|precipMM|            features|
# +-------------------+--------+--------------------+
# |-0.2260607304154405|     0.0|[-2.0,9.0,0.0,22....|
# |0.05907616912933378|     0.0|[-1.0,12.0,0.0,24...|
# |-0.6468367842249094|     0.0|[0.0,6.0,1.0,45.0...|
# |-0.4781911514782493|     0.0|[0.0,8.0,1.0,42.0...|
# |0.12395020799105794|     0.0|[0.0,13.0,0.0,33....|
# +-------------------+--------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.163669
# Root Mean Squared Error (RMSE) on test data = 4.24185

# %%
lr_predictions_gandhinagar = lr_model_gandhinagar.transform(test_df_gandhinagar)
lr_predictions_gandhinagar.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_gandhinagar = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_gandhinagar.evaluate(lr_predictions_gandhinagar))

test_result_gandhinagar = lr_model_gandhinagar.evaluate(test_df_gandhinagar)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_gandhinagar.rootMeanSquaredError)
# Out:
# +------------------+--------+--------------------+
# |        prediction|precipMM|            features|
# +------------------+--------+--------------------+
# |0.9126795485055674|     0.0|[3.9,4.0,29.0,75....|
# |0.9262164065897045|     0.0|[3.9,5.0,27.0,77....|
# | 0.998344985280192|     0.2|[5.5,16.0,10.0,66...|
# |0.8177606289379544|     0.3|[5.5,16.0,17.0,69...|
# | 0.372534945002037|     0.0|[5.7,20.0,7.0,27....|
# +------------------+--------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.316235
# Root Mean Squared Error (RMSE) on test data = 1.48029

# %%
lr_predictions_gangtok = lr_model_gangtok.transform(test_df_gangtok)
lr_predictions_gangtok.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_gangtok = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_gangtok.evaluate(lr_predictions_gangtok))

test_result_gangtok = lr_model_gangtok.evaluate(test_df_gangtok)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_gangtok.rootMeanSquaredError)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# | -0.2603831194535786|     0.0|[-26.0,25.0,0.0,9...|
# | -0.2651137407553712|     0.0|[-24.0,30.0,0.0,1...|
# | -0.2298372606700667|     0.0|[-19.0,26.0,0.0,2...|
# | -0.1769490996550367|     0.0|[-18.0,14.0,1.0,1...|
# |-0.20996185892851216|     0.0|[-17.0,28.0,1.0,2...|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.323779
# Root Mean Squared Error (RMSE) on test data = 1.52369

# %%
lr_predictions_kolkata = lr_model_kolkata.transform(test_df_kolkata)
lr_predictions_kolkata.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_kolkata = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_kolkata.evaluate(lr_predictions_kolkata))

test_result_kolkata = lr_model_kolkata.evaluate(test_df_kolkata)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_kolkata.rootMeanSquaredError)
# Out:
# +--------------------+--------+-------------------+
# |          prediction|precipMM|           features|
# +--------------------+--------+-------------------+
# |0.006926214019155...|     0.0|[0.0,42.0,10.0,0.0]|
# |-0.17360720372434035|     0.0| [1.0,0.0,10.0,1.0]|
# |-0.17360720372434035|     0.0| [1.0,0.0,10.0,1.0]|
# |-0.17360720372434035|     0.0| [1.0,0.0,10.0,1.0]|
# |-0.17360720372434035|     0.0| [1.0,0.0,10.0,1.0]|
# +--------------------+--------+-------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.146681
# Root Mean Squared Error (RMSE) on test data = 2.43829

# %%
lr_predictions_mawsynram = lr_model_mawsynram.transform(test_df_mawsynram)
lr_predictions_mawsynram.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_mawsynram = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_mawsynram.evaluate(lr_predictions_mawsynram))

test_result_mawsynram = lr_model_mawsynram.evaluate(test_df_mawsynram)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_mawsynram.rootMeanSquaredError)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# |-0.18473295471900997|     0.0|[-2.0,11.0,0.0,24...|
# |-0.01674852993003384|     0.0|[-1.0,12.0,0.0,24...|
# | 0.48766115496756157|     0.0|[-1.0,17.0,0.0,28...|
# |0.046071477581257625|     0.0|[0.0,13.0,0.0,33....|
# |  -1.032359146865474|     0.0|[1.0,3.0,0.0,50.0...|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.162619
# Root Mean Squared Error (RMSE) on test data = 4.21514

# %%
lr_predictions_meerut = lr_model_meerut.transform(test_df_meerut)
lr_predictions_meerut.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_meerut = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_meerut.evaluate(lr_predictions_meerut))

test_result_meerut = lr_model_meerut.evaluate(test_df_meerut)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_meerut.rootMeanSquaredError)
# Out:
# +-------------------+--------+-------------------+
# |         prediction|precipMM|           features|
# +-------------------+--------+-------------------+
# |0.10076473928470048|     0.0|[-7.0,20.0,0.0,4.0]|
# |0.10499840255074751|     0.0|[-6.0,15.0,1.0,4.0]|
# |0.11346572908284155|     0.0|[-6.0,17.0,3.0,4.0]|
# |0.10076473928470048|     0.0|[-6.0,19.0,0.0,5.0]|
# |0.10076473928470048|     0.0|[-6.0,21.0,0.0,6.0]|
# +-------------------+--------+-------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.0869262
# Root Mean Squared Error (RMSE) on test data = 0.755082

# %%
lr_predictions_mizoram = lr_model_mizoram.transform(test_df_mizoram)
lr_predictions_mizoram.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_mizoram = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_mizoram.evaluate(lr_predictions_mizoram))

test_result_mizoram = lr_model_mizoram.evaluate(test_df_mizoram)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_mizoram.rootMeanSquaredError)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# | -0.3530392261900843|     0.0|[5.0,11.5,1.0,0.0...|
# |-0.16018566525503353|     0.0|[5.0,11.5,2.0,0.0...|
# |-0.18337745280584095|     0.0|[5.0,11.5,5.0,0.0...|
# |-0.03393970714144068|     0.0|[5.0,11.5,6.0,0.0...|
# |-0.23098837243190573|     0.0|[6.0,11.5,1.0,0.0...|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.109464
# Root Mean Squared Error (RMSE) on test data = 2.48539

# %%
lr_predictions_mumbai = lr_model_mumbai.transform(test_df_mumbai)
lr_predictions_mumbai.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_mumbai = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_mumbai.evaluate(lr_predictions_mumbai))

test_result_mumbai = lr_model_mumbai.evaluate(test_df_mumbai)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_mumbai.rootMeanSquaredError)
# Out:
# +------------------+--------+--------------------+
# |        prediction|precipMM|            features|
# +------------------+--------+--------------------+
# |0.2815786569010186|     0.0|[23.0,11.1,6.0,18...|
# |0.2666042873849719|     0.0|[23.0,11.1,6.0,19...|
# |0.3133049530855061|     0.1|[23.0,11.1,6.0,19...|
# |0.5018851730400442|     0.0|[23.0,11.1,6.0,22...|
# |1.3011291614063367|     0.0|[23.0,11.1,6.0,31...|
# +------------------+--------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.377128
# Root Mean Squared Error (RMSE) on test data = 2.13564

# %%
lr_predictions_pune = lr_model_pune.transform(test_df_pune)
lr_predictions_pune.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_pune = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_pune.evaluate(lr_predictions_pune))

test_result_pune = lr_model_pune.evaluate(test_df_pune)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_pune.rootMeanSquaredError)
# Out:
# +------------------+--------+--------------------+
# |        prediction|precipMM|            features|
# +------------------+--------+--------------------+
# |2.3032940981756465|     8.0|[23.0,5.9,5.0,19....|
# | 2.649635458142072|    16.8|[23.0,5.9,5.0,19....|
# | 1.400586667420531|     0.4|[23.0,5.9,5.0,20....|
# |1.9623035618998745|     5.5|[23.0,5.9,5.0,20....|
# |1.1607286512837511|     1.5|[23.0,5.9,5.0,21....|
# +------------------+--------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.288717
# Root Mean Squared Error (RMSE) on test data = 1.38957

# %%
lr_predictions_rajasthan = lr_model_rajasthan.transform(test_df_rajasthan)
lr_predictions_rajasthan.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_rajasthan = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_rajasthan.evaluate(lr_predictions_rajasthan))

test_result_rajasthan = lr_model_rajasthan.evaluate(test_df_rajasthan)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_rajasthan.rootMeanSquaredError)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# | 0.31462591351263924|     0.0|[-10.0,14.0,31.0,...|
# | 0.11601575834144695|     0.0|[-10.0,20.0,0.0,1...|
# |  0.1489362345847114|     0.0|[-10.0,22.0,2.0,2...|
# |-0.01033176595560...|     0.0|[-9.0,5.0,0.0,10....|
# |   0.835491058992919|     0.0|[-9.0,10.0,100.0,...|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.156231
# Root Mean Squared Error (RMSE) on test data = 1.51314

# %%
lr_predictions_shillong = lr_model_shillong.transform(test_df_shillong)
lr_predictions_shillong.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_shillong = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_shillong.evaluate(lr_predictions_shillong))

test_result_shillong = lr_model_shillong.evaluate(test_df_shillong)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_shillong.rootMeanSquaredError)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# |-0.26702956981311843|     0.0|[-2.0,9.0,0.0,22....|
# | 0.44593436380073825|     0.0|[-1.0,16.0,0.0,25...|
# |  0.5274752479675797|     0.0|[-1.0,17.0,0.0,28...|
# | -0.6879114519316047|     0.0|[0.0,6.0,1.0,45.0...|
# | 0.09851897927124043|     0.0|[0.0,12.0,2.0,19....|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.174755
# Root Mean Squared Error (RMSE) on test data = 4.00802

# %%
lr_predictions_uttarakhand = lr_model_uttarakhand.transform(test_df_uttarakhand)
lr_predictions_uttarakhand.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_uttarakhand = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_uttarakhand.evaluate(lr_predictions_uttarakhand))

test_result_uttarakhand = lr_model_uttarakhand.evaluate(test_df_uttarakhand)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_uttarakhand.rootMeanSquaredError)
# Out:
# +-------------------+--------+--------------------+
# |         prediction|precipMM|            features|
# +-------------------+--------+--------------------+
# | 0.1998270979812422|     0.0|[-11.0,8.0,23.0,1...|
# |0.11559550177957822|     0.0| [-9.0,0.0,8.0,10.0]|
# |0.11359543581503928|     0.0| [-8.0,0.0,4.0,10.0]|
# |0.12259573265546475|     0.0|[-8.0,0.0,22.0,10.0]|
# |0.12309574914659915|     0.0|[-8.0,0.0,23.0,10.0]|
# +-------------------+--------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.306998
# Root Mean Squared Error (RMSE) on test data = 1.15457

# %%
lr_predictions_vellore = lr_model_vellore.transform(test_df_vellore)
lr_predictions_vellore.select("prediction","precipMM","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator

lr_evaluator_vellore = RegressionEvaluator(predictionCol="prediction", \
                                          labelCol="precipMM",metricName="r2")

print("R Squared (R2) on test data = %g" % lr_evaluator_vellore.evaluate(lr_predictions_vellore))

test_result_vellore = lr_model_vellore.evaluate(test_df_vellore)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result_vellore.rootMeanSquaredError)
# Out:
# +-------------------+--------+--------------------+
# |         prediction|precipMM|            features|
# +-------------------+--------+--------------------+
# | 0.2794986217471135|     0.0|[4.2,17.0,26.0,87...|
# | 0.5592316167690594|     0.0|[4.2,17.0,66.0,90...|
# | 0.7110535779155595|     0.0|[4.2,18.0,34.0,91...|
# |0.44034509388473236|     0.0|[4.2,18.0,49.0,83...|
# | 0.4613250685113783|     0.0|[4.2,18.0,52.0,88...|
# +-------------------+--------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.137349
# Root Mean Squared Error (RMSE) on test data = 1.19682

# %%
print("numIterations: %d" % trainingSummary_mysore.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_mysore.objectiveHistory))
trainingSummary_mysore.residuals.show()


predictions_mysore = lr_model_mysore.transform(test_df_mysore)
predictions_mysore.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.49999999999999994, 0.49349012853201646, 0.4793887966893396, 0.47832145121465064, 0.47804066858281047, 0.4779598000893803, 0.4779585733612399, 0.47795545110404863, 0.4779547736015602, 0.4779546468810128, 0.47795463028530344]
# +--------------------+
# |           residuals|
# +--------------------+
# |-0.11571735768158498|
# |-0.11629119633537277|
# |-0.11686503498916057|
# |-0.11686503498916057|
# |-0.11686503498916057|
# |-0.11686503498916057|
# |-0.11686503498916057|
# |-0.11686503498916057|
# |-0.11686503498916057|
# |-0.11686503498916057|
# |-0.11686503498916057|
# |-0.11743887364294847|
# |-0.11743887364294847|
# |-0.11743887364294847|
# |-0.11743887364294847|
# |-0.11743887364294847|
# |-0.11743887364294847|
# |-0.11743887364294847|
# |  0.8712656835368311|
# |-0.11743887364294847|
# +--------------------+
# only showing top 20 rows
#
# +-------------------+--------+--------------------+
# ...

# %%
print("numIterations: %d" % trainingSummary_bangalore.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_bangalore.objectiveHistory))
trainingSummary_bangalore.residuals.show()


predictions_bangalore = lr_model_bangalore.transform(test_df_bangalore)
predictions_bangalore.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.5, 0.48562079721045404, 0.42250127733206566, 0.4193227986775211, 0.4189442417539387, 0.41893984118563043, 0.4189390505761929, 0.41893895076851717, 0.41893894631331374, 0.4189389445306338, 0.4189389442025198]
# +--------------------+
# |           residuals|
# +--------------------+
# |-0.22608437958926775|
# |-0.21910819261764702|
# |-0.22608437958926775|
# |-0.26096531444737225|
# |-0.33770337113520155|
# |-0.27491768839061415|
# | -0.4493223626811358|
# |-0.49815567148248174|
# | -0.5795365327446241|
# |   -0.64465559788652|
# | -0.6655841588013827|
# | -0.6725603457730034|
# |  -0.693488906687866|
# | -0.8330126461202831|
# |-0.37258430599330605|
# | -0.4283938017662732|
# |  -0.491179484510861|
# | -0.5469889802838277|
# |-0.23070322394327814|
# | -0.6707269359074266|
# +--------------------+
# only showing top 20 rows
#
# +-------------------+--------+--------------------+
# |         prediction|precipMM|            features|
# ...

# %%
print("numIterations: %d" % trainingSummary_bhopal.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_bhopal.objectiveHistory))
trainingSummary_bhopal.residuals.show()


predictions_bhopal = lr_model_bhopal.transform(test_df_bhopal)
predictions_bhopal.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.49999999999999994, 0.4825020712715676, 0.4394219857704568, 0.4354772102135536, 0.4325496447831641, 0.4320542061552115, 0.43177538447962094, 0.4316656821939614, 0.4314547026029522, 0.43145350847853237, 0.4314523680268065]
# +--------------------+
# |           residuals|
# +--------------------+
# |-0.11573682412350417|
# |-0.11573682412350417|
# |  -0.170188098789962|
# |-0.07489836812366013|
# | -0.2766195653804684|
# |-0.07489836812366013|
# |-0.07489836812366013|
# | -0.1293496427901184|
# |-0.15657528012334776|
# |-0.18380091745657667|
# | 0.04761699987587109|
# |0.020391362542641733|
# |-0.02044709345720186|
# | -0.1986536502110683|
# |-0.07489836812366013|
# |-0.10212400545688949|
# |  -0.170188098789962|
# |-0.19741373612319135|
# |-0.21102655478980603|
# |-0.21102655478980603|
# +--------------------+
# only showing top 20 rows
#
# +-------------------+--------+--------------------+
# ...

# %%
print("numIterations: %d" % trainingSummary_cherrapunji.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_cherrapunji.objectiveHistory))
trainingSummary_cherrapunji.residuals.show()


predictions_cherrapunji = lr_model_cherrapunji.transform(test_df_cherrapunji)
predictions_cherrapunji.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.49999999999999994, 0.47911675440240464, 0.4444032359417167, 0.443489371829054, 0.4418118741925977, 0.4417881203928256, 0.4417853738227711, 0.44178349664357697, 0.4417826676297204, 0.44178258051365854, 0.44178257151071]
# +--------------------+
# |           residuals|
# +--------------------+
# |  0.1090323256051704|
# |  0.2971267358634506|
# |0.011452698306513298|
# |-0.49960189049544823|
# | -0.5839247068687783|
# |-0.14312788783997377|
# | -0.1315122833334641|
# |   1.139250831190104|
# |  0.8738686565151994|
# |  0.9968128729358412|
# |  0.8346651541337167|
# |   0.673049516030531|
# |  0.6984590694745307|
# |  0.6722513949821334|
# |  0.5560211112202609|
# | 0.31711265138721956|
# | 0.06414420226722228|
# | -0.5639387913450093|
# |  0.9122290735262695|
# |  0.8606118455898724|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+--------+--------------------+
# ...

# %%
print("numIterations: %d" % trainingSummary_gandhinagar.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_gandhinagar.objectiveHistory))
trainingSummary_gandhinagar.residuals.show()


predictions_gandhinagar = lr_model_gandhinagar.transform(test_df_gandhinagar)
predictions_gandhinagar.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.5, 0.48243087596137896, 0.4292897904903904, 0.42337171829224196, 0.4204346120439039, 0.41967246615823034, 0.4195542966274679, 0.41934962544864157, 0.4193336081119897, 0.41932812710416145, 0.4193267733085238]
# +--------------------+
# |           residuals|
# +--------------------+
# | -0.8485538980206906|
# | -0.8357481655657399|
# | -0.9145042471808287|
# | -0.6328033579072194|
# | -0.7486692895255032|
# | -0.7609015136679687|
# |-0.24182304925024622|
# | -0.5345979282743444|
# |  -0.467412078626134|
# | -0.4106225366781211|
# |-0.36611594903148426|
# |-0.36065351064107976|
# |  0.9677648148798865|
# | -0.6349998880831366|
# |  -0.763155959530479|
# |  0.8217658803048682|
# | -0.5532949665702027|
# |-0.45304615197041453|
# |   3.592008317538806|
# |  3.5306289177650716|
# +--------------------+
# only showing top 20 rows
#
# +-------------------+--------+--------------------+
# |         prediction|precipMM|            features|
# ...

# %%
print("numIterations: %d" % trainingSummary_gangtok.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_gangtok.objectiveHistory))
trainingSummary_gangtok.residuals.show()


predictions_gangtok = lr_model_gangtok.transform(test_df_gangtok)
predictions_gangtok.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.5000000000000001, 0.4783157934614122, 0.42478327883369477, 0.41864309684778717, 0.4137762311253579, 0.4136106439460667, 0.41358810879733904, 0.41357369995416343, 0.4135691793970393, 0.4135656923125023, 0.41356399886069967]
# +-------------------+
# |          residuals|
# +-------------------+
# |0.23919691343458283|
# | 0.2627484301044767|
# |0.27766100433410656|
# | 0.2752956936832085|
# |0.23055797099431885|
# | 0.1764605955409131|
# |0.22747195001916864|
# | 0.1968245013965877|
# | 0.2298372606700667|
# | 1.2112901710445207|
# |0.14118411545560505|
# |0.21255937578953876|
# |0.23220257132096123|
# |0.17728289570423428|
# |0.18036891667938448|
# |0.12133280540791347|
# |  0.169364663588226|
# |0.18036891667938448|
# |0.10272002455608487|
# |0.19528149090901437|
# +-------------------+
# only showing top 20 rows
#
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# ...

# %%
print("numIterations: %d" % trainingSummary_kolkata.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_kolkata.objectiveHistory))
trainingSummary_kolkata.residuals.show()


predictions_kolkata = lr_model_kolkata.transform(test_df_kolkata)
predictions_kolkata.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.5, 0.48926079571762165, 0.4542262939230237, 0.4532732283702134, 0.4530623154354876, 0.45299492862716123, 0.4529943731654633, 0.4529939784326829, 0.4529939438077971, 0.45299393550071854, 0.45299393531597426]
# +-------------------+
# |          residuals|
# +-------------------+
# |0.19998473066561284|
# |0.19998473066561284|
# |0.17360720372434035|
# |0.17360720372434035|
# |0.17360720372434035|
# |0.17360720372434035|
# |0.17360720372434035|
# |0.17360720372434035|
# |0.17360720372434035|
# |0.17360720372434035|
# |0.17360720372434035|
# |0.17360720372434035|
# |0.17360720372434035|
# |0.16868075266041704|
# |0.16868075266041704|
# |0.16868075266041704|
# |0.16375430159649418|
# |0.16375430159649418|
# |0.16375430159649418|
# |  0.153901399468648|
# +-------------------+
# only showing top 20 rows
#
# +--------------------+--------+-------------------+
# |          prediction|precipMM|           features|
# ...

# %%
print("numIterations: %d" % trainingSummary_mawsynram.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_mawsynram.objectiveHistory))
trainingSummary_mawsynram.residuals.show()


predictions_mawsynram = lr_model_mawsynram.transform(test_df_mawsynram)
predictions_mawsynram.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.4999999999999999, 0.47891263157539726, 0.4436477614262538, 0.44273686077460456, 0.440977838063209, 0.4409616771737658, 0.44095683456335294, 0.4409554764410407, 0.4409542015531403, 0.44095254646136156, 0.4409524275768157]
# +--------------------+
# |           residuals|
# +--------------------+
# |  0.2918488531281298|
# | 0.36146010777967064|
# | 0.09464610232257797|
# |-0.40781210144358226|
# |   0.696546935616766|
# |  0.5368488285688002|
# |-0.07211222474657575|
# |-0.04886067667600713|
# |  1.1646780744765977|
# |  0.8997032155992528|
# |  0.8725487052658139|
# |   0.714189030489365|
# |  0.7393920596913759|
# |  0.6070731320802452|
# |  0.2650384187736563|
# | 0.13065567547940304|
# |-0.21405590237024086|
# |  1.0493881928781619|
# |   0.942047625365646|
# |  0.8894654167268001|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+--------+--------------------+
# ...

# %%
print("numIterations: %d" % trainingSummary_meerut.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_meerut.objectiveHistory))
trainingSummary_meerut.residuals.show()


predictions_meerut = lr_model_meerut.transform(test_df_meerut)
predictions_meerut.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.5, 0.49859490020855346, 0.4926419711563083, 0.4923552550450966, 0.49230491826976364, 0.4923022857768396, 0.49230209751980514, 0.4923020840570107, 0.4923020830942481, 0.4923020830253982, 0.49230208302047457]
# +--------------------+
# |           residuals|
# +--------------------+
# |-0.10076473928470048|
# |-0.10076473928470048|
# |-0.10076473928470048|
# |-0.11769939234888858|
# |-0.10076473928470048|
# |-0.10076473928470048|
# |-0.10076473928470048|
# |-0.10076473928470048|
# |-0.10076473928470048|
# |-0.10076473928470048|
# |-0.10076473928470048|
# |-0.10076473928470048|
# |-0.10076473928470048|
# |-0.10076473928470048|
# |-0.10076473928470048|
# |-0.13040038214702968|
# |-0.10076473928470048|
# |-0.10076473928470048|
# |-0.12616671888098263|
# |-0.11346572908284155|
# +--------------------+
# only showing top 20 rows
#
# +-------------------+--------+--------------------+
# |         prediction|precipMM|            features|
# ...

# %%
print("numIterations: %d" % trainingSummary_mizoram.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_mizoram.objectiveHistory))
trainingSummary_mizoram.residuals.show()


predictions_mizoram = lr_model_mizoram.transform(test_df_mizoram)
predictions_mizoram.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.5, 0.48503004303393, 0.45994137278081515, 0.4584983503768873, 0.4603098678406048, 0.45894427972202445, 0.45837367068714696, 0.45776315776222287, 0.4576185703332532, 0.45749243468873074, 0.45742577156893216]
# +--------------------+
# |           residuals|
# +--------------------+
# | 0.31480776855183557|
# | 0.21095030384545055|
# | 0.27940258620156655|
# | 0.22995464456450776|
# | 0.11458314700181482|
# |  0.0743139242236115|
# |  0.0407827851751108|
# | 0.12699371909429757|
# | 0.02624886037376406|
# |-0.00882887830013...|
# |-0.02555663255595...|
# |0.045959485283846746|
# | 0.17043177166015333|
# |0.055521364291827524|
# | 0.17868426068799614|
# | 0.05764489750200852|
# | 0.05418776433582906|
# |  0.1723469279404224|
# | 0.14271743607756093|
# |-0.03504055779597515|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# ...

# %%
print("numIterations: %d" % trainingSummary_mumbai.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_mumbai.objectiveHistory))
trainingSummary_mumbai.residuals.show()


predictions_mumbai = lr_model_mumbai.transform(test_df_mumbai)
predictions_mumbai.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.5, 0.4664591735796355, 0.4102489183741078, 0.4049714103433262, 0.3963351539551809, 0.3947387760389616, 0.39437603637075036, 0.3939266934477179, 0.3938375946687986, 0.39360021742426493, 0.39354214344745886]
# +--------------------+
# |           residuals|
# +--------------------+
# |4.028944545879653...|
# |-0.18817732549995014|
# | -1.1442752376362861|
# |-0.09299843694648047|
# |-0.09299843694648047|
# |-0.15645102931545551|
# |-0.15645102931545551|
# |-0.23487799120048436|
# | -0.3600056187860403|
# | -0.2983305835694594|
# |-0.39173191497053494|
# |-0.42345821115502247|
# | -0.5952865044411126|
# |  -0.705439762510629|
# | -0.9874213138662427|
# | -1.0341219795667698|
# |-0.05321444233931...|
# |-0.32022162417887756|
# |-0.32022162417887756|
# | -0.6489038412350254|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# ...

# %%
print("numIterations: %d" % trainingSummary_pune.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_pune.objectiveHistory))
trainingSummary_pune.residuals.show()


predictions_pune = lr_model_pune.transform(test_df_pune)
predictions_pune.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.5000000000000001, 0.4876484800383236, 0.4593249592992983, 0.45138151071996674, 0.44832699703337164, 0.4477923024996924, 0.4477034880568997, 0.44765706651851117, 0.44764452419023665, 0.4476378275711506, 0.4476365660313186]
# +-------------------+
# |          residuals|
# +-------------------+
# |-0.7638210312478311|
# |-0.8649535513868223|
# | 0.6960223687139035|
# | 0.3940559123374041|
# | 0.9561577560257102|
# |  1.233550037836288|
# |-0.9230557175194605|
# |-0.9446827767632087|
# | 1.2376964381001256|
# |  2.243047261790778|
# |  4.804023181891504|
# |  4.143047261790778|
# | 5.0913550781337005|
# | 18.845013718167277|
# |-1.4415772036963037|
# | 25.614411783351663|
# |    4.9808786532998|
# |0.44454881105281707|
# | 0.5250283343423228|
# |-2.4959768181084963|
# +-------------------+
# only showing top 20 rows
#
# +------------------+--------+--------------------+
# |        prediction|precipMM|            features|
# ...

# %%
print("numIterations: %d" % trainingSummary_rajasthan.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_rajasthan.objectiveHistory))
trainingSummary_rajasthan.residuals.show()


predictions_rajasthan = lr_model_rajasthan.transform(test_df_rajasthan)
predictions_rajasthan.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.5, 0.4931745260284585, 0.47292472045852135, 0.4720886672574345, 0.47162945681795876, 0.4715207865089088, 0.4714739217776585, 0.4714727990086647, 0.4714724120769328, 0.471472283068464, 0.47147223600328964]
# +--------------------+
# |           residuals|
# +--------------------+
# |-0.13286209491438794|
# |-0.04863041204968388|
# |-0.07389991690909503|
# |-0.07389991690909503|
# | -0.0907462534820358|
# |-0.10720649160366813|
# |-0.15581500906594714|
# |-0.14932233303602005|
# | -0.1497084314873287|
# |-0.05705358033615...|
# |-0.07389991690909503|
# |-0.08232308519556542|
# |-0.08232308519556542|
# | -0.0907462534820358|
# | -0.0907462534820358|
# | -0.0907462534820358|
# | -0.0907462534820358|
# |-0.12366672972530024|
# |-0.11601575834144695|
# |-0.11601575834144695|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# ...

# %%
print("numIterations: %d" % trainingSummary_shillong.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_shillong.objectiveHistory))
trainingSummary_shillong.residuals.show()


predictions_shillong = lr_model_shillong.transform(test_df_shillong)
predictions_shillong.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.5, 0.4791357923055118, 0.4451027936936655, 0.44425240312455827, 0.44257962225565484, 0.44256618437676326, 0.44255558721614335, 0.4425531642296232, 0.4425516879771343, 0.4425494432677863, 0.4425489094117309]
# +--------------------+
# |           residuals|
# +--------------------+
# |  0.1580763618159864|
# | 0.34136606671334846|
# |-0.01151370646027...|
# |  0.0693310903825477|
# |  0.5248296835979289|
# |-0.07284665406342583|
# |  -0.070584919479316|
# |   1.170996280964495|
# |  0.9015713025673904|
# |   0.737619534922473|
# |  0.7121211217018768|
# | 0.24680858266135175|
# | 0.35506570333445353|
# |-0.24243672233968994|
# |  1.0536208624151016|
# |   0.948495475637344|
# |  0.8943669153007932|
# |  0.7096145549658814|
# |   1.026208538584811|
# |-0.14774329605693026|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# ...

# %%
print("numIterations: %d" % trainingSummary_uttarakhand.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_uttarakhand.objectiveHistory))
trainingSummary_uttarakhand.residuals.show()


predictions_uttarakhand = lr_model_uttarakhand.transform(test_df_uttarakhand)
predictions_uttarakhand.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.49999999999999994, 0.4880319324006362, 0.44751366644987217, 0.4453465074354525, 0.4447541617683699, 0.4446896497736698, 0.44468647904257136, 0.44468566716716357, 0.4446855604943546, 0.44468555015318956, 0.4446855491181551]
# +--------------------+
# |           residuals|
# +--------------------+
# |-0.17005280918598142|
# |-0.18973566288577715|
# | -0.1220957161643299|
# |-0.12409578212886885|
# |-0.17914421129917724|
# |-0.22510123835629003|
# | -0.1220957161643299|
# |-0.12309574914659915|
# | -0.1250958151111381|
# | -0.1260958480934078|
# |-0.14377863582866413|
# |-0.18564442568392892|
# |-0.11709555125298232|
# |-0.12009565019979096|
# |-0.12159569967319506|
# |-0.12409578212886885|
# | -0.1245957986200037|
# |-0.12468690389277404|
# |-0.13218715125979497|
# |  -0.135687266697738|
# +--------------------+
# only showing top 20 rows
#
# +-------------------+--------+--------------------+
# ...

# %%
print("numIterations: %d" % trainingSummary_vellore.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary_vellore.objectiveHistory))
trainingSummary_vellore.residuals.show()


predictions_vellore = lr_model_vellore.transform(test_df_vellore)
predictions_vellore.select("prediction","precipMM","features").show()
# Out:
# numIterations: 11
# objectiveHistory: [0.5, 0.49477463954148215, 0.476532663926863, 0.4751944464178214, 0.47491318895305445, 0.47488921220146496, 0.4748850055312191, 0.4748839853523629, 0.47488374269061867, 0.4748836835892808, 0.47488367010699783]
# +--------------------+
# |           residuals|
# +--------------------+
# | -0.5522382918935107|
# |-0.20257204811607843|
# | -0.4978703111699989|
# | -0.3074719212493081|
# | -0.3144652461248567|
# | -0.4123717943825378|
# | -0.4543317436358297|
# |  -1.104258389227161|
# | -0.5081848908978999|
# | -0.6151782157734484|
# | -0.6361581904000945|
# | -0.7200780889066781|
# | -0.7270714137822268|
# | -0.7970046625377133|
# |-0.21655869786717574|
# | -0.5188502857966448|
# | -0.4123717943825378|
# | -0.4333517690091837|
# |-0.26132506851137827|
# | -1.0692917648494178|
# +--------------------+
# only showing top 20 rows
#
# +-------------------+--------+--------------------+
# |         prediction|precipMM|            features|
# ...

# %%
# ML - Decision tree regression with PySpark and MLlib

# %%
dt = DecisionTreeRegressor(featuresCol ='features', labelCol = 'precipMM')

dt_model_mysore = dt.fit(train_df_mysore)
dt_predictions_mysore = dt_model_mysore.transform(test_df_mysore)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions_mysore)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions_mysore)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 1.22643
# R Squared (R2) on test data = 0.557124

# %%
dt_model_bangalore = dt.fit(train_df_bangalore)
dt_predictions = dt_model_bangalore.transform(test_df_bangalore)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions_mysore)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 0.97038
# R Squared (R2) on test data = 0.557124

# %%
dt_model_bhopal = dt.fit(train_df_bhopal)
dt_predictions = dt_model_bhopal.transform(test_df_bhopal)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 2.14732
# R Squared (R2) on test data = 0.444773

# %%
dt_model_cherrapunji = dt.fit(train_df_cherrapunji)
dt_predictions = dt_model_cherrapunji.transform(test_df_cherrapunji)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 2.93491
# R Squared (R2) on test data = 0.599634

# %%
dt_model_gandhinagar = dt.fit(train_df_gandhinagar)
dt_predictions = dt_model_gandhinagar.transform(test_df_gandhinagar)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 1.03806
# R Squared (R2) on test data = 0.663752

# %%
dt_model_gangtok = dt.fit(train_df_gangtok)
dt_predictions = dt_model_gangtok.transform(test_df_gangtok)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 1.39502
# R Squared (R2) on test data = 0.433166

# %%
dt_model_kolkata = dt.fit(train_df_kolkata)
dt_predictions = dt_model_kolkata.transform(test_df_kolkata)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 2.18369
# R Squared (R2) on test data = 0.315574

# %%
dt_model_mawsynram = dt.fit(train_df_mawsynram)
dt_predictions = dt_model_mawsynram.transform(test_df_mawsynram)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 2.97339
# R Squared (R2) on test data = 0.583319

# %%
dt_model_meerut = dt.fit(train_df_meerut)
dt_predictions = dt_model_meerut.transform(test_df_meerut)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 0.682194
# R Squared (R2) on test data = 0.254696

# %%
dt_model_mizoram = dt.fit(train_df_mizoram)
dt_predictions = dt_model_mizoram.transform(test_df_mizoram)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 2.41498
# R Squared (R2) on test data = 0.159204

# %%
dt_model_mumbai = dt.fit(train_df_mumbai)
dt_predictions = dt_model_mumbai.transform(test_df_mumbai)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 2.30394
# R Squared (R2) on test data = 0.27509

# %%
dt_model_pune = dt.fit(train_df_pune)
dt_predictions = dt_model_pune.transform(test_df_pune)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 1.36929
# R Squared (R2) on test data = 0.309336

# %%
dt_model_rajasthan = dt.fit(train_df_rajasthan)
dt_predictions = dt_model_rajasthan.transform(test_df_rajasthan)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 1.1642
# R Squared (R2) on test data = 0.500515

# %%
dt_model_shillong = dt.fit(train_df_shillong)
dt_predictions = dt_model_shillong.transform(test_df_shillong)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 2.56973
# R Squared (R2) on test data = 0.660766

# %%
dt_model_uttarakhand = dt.fit(train_df_uttarakhand)
dt_predictions = dt_model_uttarakhand.transform(test_df_uttarakhand)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 0.709707
# R Squared (R2) on test data = 0.738149

# %%
dt_model_vellore = dt.fit(train_df_vellore)
dt_predictions = dt_model_vellore.transform(test_df_vellore)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

dt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = dt_evaluator.evaluate(dt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 0.900905
# R Squared (R2) on test data = 0.511195

# %%
dt_model_mysore.featureImportances
# Out:
# SparseVector(4, {0: 0.192, 1: 0.0826, 2: 0.0951, 3: 0.6302})

# %%
dt_model_bangalore.featureImportances
# Out:
# SparseVector(5, {0: 0.0028, 1: 0.0909, 2: 0.0238, 3: 0.0005, 4: 0.8821})

# %%
dt_model_bhopal.featureImportances
# Out:
# SparseVector(6, {0: 0.0516, 1: 0.045, 2: 0.0965, 3: 0.001, 4: 0.0156, 5: 0.7903})

# %%
dt_model_cherrapunji.featureImportances
# Out:
# SparseVector(6, {0: 0.0016, 1: 0.0556, 2: 0.0449, 3: 0.334, 4: 0.0128, 5: 0.5511})

# %%
dt_model_gandhinagar.featureImportances
# Out:
# SparseVector(7, {0: 0.0157, 1: 0.016, 2: 0.0556, 3: 0.0176, 4: 0.018, 5: 0.0246, 6: 0.8525})

# %%
dt_model_gangtok.featureImportances
# Out:
# SparseVector(7, {0: 0.0223, 1: 0.0033, 2: 0.1499, 3: 0.0136, 4: 0.0221, 5: 0.741, 6: 0.0479})

# %%
dt_model_kolkata.featureImportances
# Out:
# SparseVector(4, {0: 0.0326, 1: 0.0402, 2: 0.782, 3: 0.1453})

# %%
dt_model_mawsynram.featureImportances
# Out:
# SparseVector(6, {0: 0.0021, 1: 0.1074, 2: 0.0084, 3: 0.3121, 4: 0.025, 5: 0.5449})

# %%
dt_model_meerut.featureImportances
# Out:
# SparseVector(4, {0: 0.2007, 1: 0.3207, 2: 0.3891, 3: 0.0895})

# %%
dt_model_mizoram.featureImportances
# Out:
# SparseVector(6, {1: 0.042, 2: 0.2866, 3: 0.4816, 4: 0.1824, 5: 0.0074})

# %%
dt_model_mumbai.featureImportances
# Out:
# SparseVector(9, {0: 0.0812, 1: 0.02, 2: 0.0006, 3: 0.0457, 4: 0.0402, 5: 0.0632, 6: 0.2914, 7: 0.4525, 8: 0.0051})

# %%
dt_model_pune.featureImportances
# Out:
# SparseVector(8, {0: 0.0143, 1: 0.0, 2: 0.0015, 3: 0.0115, 4: 0.0942, 5: 0.0, 6: 0.0099, 7: 0.8686})

# %%
dt_model_rajasthan.featureImportances
# Out:
# SparseVector(5, {0: 0.0916, 1: 0.1589, 2: 0.0174, 3: 0.0904, 4: 0.6417})

# %%
dt_model_shillong.featureImportances
# Out:
# SparseVector(6, {0: 0.0018, 1: 0.044, 2: 0.0433, 3: 0.3749, 4: 0.0164, 5: 0.5197})

# %%
dt_model_uttarakhand.featureImportances
# Out:
# SparseVector(4, {0: 0.0419, 1: 0.0393, 2: 0.026, 3: 0.8927})

# %%
dt_model_vellore.featureImportances
# Out:
# SparseVector(5, {0: 0.0093, 1: 0.2237, 2: 0.0577, 3: 0.032, 4: 0.6773})

# %%
mysore_df.take(1)
# Out:
# [Row(features=DenseVector([18.0, 24.0, 90.0, 10.0]), precipMM=0.0)]

# %%
bangalore_df.take(1)
# Out:
# [Row(features=DenseVector([11.6, 17.0, 28.0, 89.0, 10.0]), precipMM=0.0)]

# %%
bhopal_df.take(1)
# Out:
# [Row(features=DenseVector([0.0, 8.0, 0.0, 31.0, 1018.0, 10.0]), precipMM=0.0)]

# %%
cherrapunji_df.take(1)
# Out:
# [Row(features=DenseVector([9.0, 3.0, 54.0, 94.0, 1017.0, 10.0]), precipMM=0.0)]

# %%
gandhinagar_df.take(1)
# Out:
# [Row(features=DenseVector([10.9, 4.0, 27.0, 0.0, 36.0, 1017.0, 10.0]), precipMM=0.0)]

# %%
gangtok_df.take(1)
# Out:
# [Row(features=DenseVector([-1.0, 6.0, 0.0, 50.0, 1016.0, 10.0, 3.0]), precipMM=0.0)]

# %%
kolkata_df.take(1)
# Out:
# [Row(features=DenseVector([10.0, 0.0, 10.0, 9.0]), precipMM=0.0)]

# %%
mawsynram_df.take(1)
# Out:
# [Row(features=DenseVector([9.0, 3.0, 54.0, 94.0, 1017.0, 10.0]), precipMM=0.0)]

# %%
meerut_df.take(1)
# Out:
# [Row(features=DenseVector([-2.0, 23.0, 0.0, 39.0]), precipMM=0.0)]

# %%
mizoram_df.take(1)
# Out:
# [Row(features=DenseVector([7.0, 8.7, 4.0, 0.0, 71.0, 1016.0]), precipMM=0.0)]

# %%
mumbai_df.take(1)
# Out:
# [Row(features=DenseVector([31.0, 11.1, 7.0, 7.0, 8.0, 59.0, 1015.0, 10.0, 5.0]), precipMM=0.0)]

# %%
pune_df.take(1)
# Out:
# [Row(features=DenseVector([30.0, 11.1, 6.0, 8.0, 9.0, 45.0, 1016.0, 10.0]), precipMM=0.0)]

# %%
rajasthan_df.take(1)
# Out:
# [Row(features=DenseVector([-4.0, 20.0, 1.0, 26.0, 10.0]), precipMM=0.0)]

# %%
shillong_df.take(1)
# Out:
# [Row(features=DenseVector([9.0, 3.0, 54.0, 94.0, 1017.0, 10.0]), precipMM=0.0)]

# %%
uttarakhand_df.take(1)
# Out:
# [Row(features=DenseVector([2.0, 1.0, 47.0, 10.0]), precipMM=0.0)]

# %%
vellore_df.take(1)
# Out:
# [Row(features=DenseVector([11.6, 19.0, 44.0, 93.0, 10.0]), precipMM=0.0)]

# %%
# ML - Gradient-boosted tree regression with PySpark and MLlib

# %%
from pyspark.ml.regression import GBTRegressor

gbt = GBTRegressor(featuresCol = 'features', labelCol = 'precipMM', maxIter=10)
gbt_model = gbt.fit(train_df_mysore)
gbt_predictions = gbt_model.transform(test_df_mysore)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")
rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+-------------------+
# |          prediction|precipMM|           features|
# +--------------------+--------+-------------------+
# | 0.00817927524602232|     0.0|[0.0,0.0,12.0,10.0]|
# | 0.00817927524602232|     0.0|[1.0,0.0,11.0,10.0]|
# | 0.00817927524602232|     0.0|[1.0,0.0,11.0,10.0]|
# | 0.00817927524602232|     0.0|[1.0,0.0,13.0,10.0]|
# |0.028539184683648397|     0.0|[1.0,0.0,13.0,20.0]|
# +--------------------+--------+-------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 1.21921
# R Squared (R2) on test data = 0.562322

# %%
gbt_model = gbt.fit(train_df_bangalore)
gbt_predictions = gbt_model.transform(test_df_bangalore)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)


gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# |-0.01785352085053808|     0.0|[4.2,16.0,36.0,78...|
# |-0.03312154086175...|     0.0|[4.2,16.0,36.0,92...|
# |-0.01121572156373...|     0.0|[4.2,16.0,37.0,86...|
# |-0.01121572156373...|     0.0|[4.2,16.0,39.0,89...|
# |-0.01121572156373...|     0.0|[4.2,16.0,40.0,90...|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 0.9236
# R Squared (R2) on test data = 0.723964

# %%
gbt_model = gbt.fit(train_df_bhopal)
gbt_predictions = gbt_model.transform(test_df_bhopal)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)


gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# |4.550525546026579...|     0.0|[-11.0,16.0,0.0,4...|
# |4.550525546026579...|     0.0|[-10.0,20.0,0.0,4...|
# |4.550525546026579...|     0.0|[-9.0,9.0,0.0,5.0...|
# |4.550525546026579...|     0.0|[-9.0,10.0,0.0,4....|
# |4.550525546026579...|     0.0|[-9.0,13.0,0.0,4....|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 1.55648
# R Squared (R2) on test data = 0.708283

# %%
gbt_model = gbt.fit(train_df_cherrapunji)
gbt_predictions = gbt_model.transform(test_df_cherrapunji)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)
gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# |0.021127346163775852|     0.0|[-2.0,9.0,0.0,22....|
# |0.012576459725531692|     0.0|[-1.0,12.0,0.0,24...|
# |0.007288708331622042|     0.0|[0.0,6.0,1.0,45.0...|
# |0.007981316696895962|     0.0|[0.0,8.0,1.0,42.0...|
# |0.012576459725531692|     0.0|[0.0,13.0,0.0,33....|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 2.87496
# R Squared (R2) on test data = 0.615825

# %%
gbt_model = gbt.fit(train_df_gandhinagar)
gbt_predictions = gbt_model.transform(test_df_gandhinagar)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)
gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")
rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# | 0.05744263227911619|     0.0|[3.9,4.0,29.0,75....|
# | 0.05744263227911619|     0.0|[3.9,5.0,27.0,77....|
# |   1.292256722298686|     0.2|[5.5,16.0,10.0,66...|
# | 0.05744263227911619|     0.3|[5.5,16.0,17.0,69...|
# |-0.00402080223194...|     0.0|[5.7,20.0,7.0,27....|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 1.03362
# R Squared (R2) on test data = 0.666626

# %%
gbt_model = gbt.fit(train_df_gangtok)
gbt_predictions = gbt_model.transform(test_df_gangtok)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)
gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# |-8.30512329830026...|     0.0|[-26.0,25.0,0.0,9...|
# |-8.30512329830026...|     0.0|[-24.0,30.0,0.0,1...|
# |-8.30512329830026...|     0.0|[-19.0,26.0,0.0,2...|
# |-8.30512329830026...|     0.0|[-18.0,14.0,1.0,1...|
# |-8.30512329830026...|     0.0|[-17.0,28.0,1.0,2...|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 1.38999
# R Squared (R2) on test data = 0.437246

# %%
gbt_model = gbt.fit(train_df_kolkata)
gbt_predictions = gbt_model.transform(test_df_kolkata)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+-------------------+
# |          prediction|precipMM|           features|
# +--------------------+--------+-------------------+
# | 0.09621041589882684|     0.0|[0.0,42.0,10.0,0.0]|
# |0.005179257135109919|     0.0| [1.0,0.0,10.0,1.0]|
# |0.005179257135109919|     0.0| [1.0,0.0,10.0,1.0]|
# |0.005179257135109919|     0.0| [1.0,0.0,10.0,1.0]|
# |0.005179257135109919|     0.0| [1.0,0.0,10.0,1.0]|
# +--------------------+--------+-------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 2.1786
# R Squared (R2) on test data = 0.318762

# %%
gbt_model = gbt.fit(train_df_mawsynram)
gbt_predictions = gbt_model.transform(test_df_mawsynram)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")

rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# |0.027395955139887913|     0.0|[-2.0,11.0,0.0,24...|
# |0.027395955139887913|     0.0|[-1.0,12.0,0.0,24...|
# | 0.04677229834562175|     0.0|[-1.0,17.0,0.0,28...|
# |0.027395955139887913|     0.0|[0.0,13.0,0.0,33....|
# |-0.02894290622829601|     0.0|[1.0,3.0,0.0,50.0...|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 2.78203
# R Squared (R2) on test data = 0.635226

# %%
gbt_model = gbt.fit(train_df_meerut)
gbt_predictions = gbt_model.transform(test_df_meerut)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)
gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")
rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+-------------------+
# |          prediction|precipMM|           features|
# +--------------------+--------+-------------------+
# |0.001654683477294...|     0.0|[-7.0,20.0,0.0,4.0]|
# |0.001654683477294...|     0.0|[-6.0,15.0,1.0,4.0]|
# |0.001654683477294...|     0.0|[-6.0,17.0,3.0,4.0]|
# |0.001654683477294...|     0.0|[-6.0,19.0,0.0,5.0]|
# |0.001654683477294...|     0.0|[-6.0,21.0,0.0,6.0]|
# +--------------------+--------+-------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 0.678181
# R Squared (R2) on test data = 0.26344

# %%
gbt_model = gbt.fit(train_df_mizoram)
gbt_predictions = gbt_model.transform(test_df_mizoram)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)
gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")
rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# |-0.00230505445328...|     0.0|[5.0,11.5,1.0,0.0...|
# |-0.00132053980915...|     0.0|[5.0,11.5,2.0,0.0...|
# |-0.00230505445328...|     0.0|[5.0,11.5,5.0,0.0...|
# |-0.00230505445328...|     0.0|[5.0,11.5,6.0,0.0...|
# |-0.00230505445328...|     0.0|[6.0,11.5,1.0,0.0...|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 2.29387
# R Squared (R2) on test data = 0.241421

# %%
gbt_model = gbt.fit(train_df_mumbai)
gbt_predictions = gbt_model.transform(test_df_mumbai)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)
gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")
rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# | 0.16985599596249926|     0.0|[23.0,11.1,6.0,18...|
# |-0.00758578639307...|     0.0|[23.0,11.1,6.0,19...|
# | 0.16985599596249926|     0.1|[23.0,11.1,6.0,19...|
# |-0.00758578639307...|     0.0|[23.0,11.1,6.0,22...|
# |-0.00758578639307...|     0.0|[23.0,11.1,6.0,31...|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 2.22283
# R Squared (R2) on test data = 0.325232

# %%
gbt_model = gbt.fit(train_df_pune)
gbt_predictions = gbt_model.transform(test_df_pune)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)
gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")
rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +------------------+--------+--------------------+
# |        prediction|precipMM|            features|
# +------------------+--------+--------------------+
# | 8.287790129407066|     8.0|[23.0,5.9,5.0,19....|
# | 27.40990732299357|    16.8|[23.0,5.9,5.0,19....|
# |13.250580374503475|     0.4|[23.0,5.9,5.0,20....|
# | 6.332297496537972|     5.5|[23.0,5.9,5.0,20....|
# |1.6114607197585005|     1.5|[23.0,5.9,5.0,21....|
# +------------------+--------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 1.32994
# R Squared (R2) on test data = 0.348453

# %%
gbt_model = gbt.fit(train_df_rajasthan)
gbt_predictions = gbt_model.transform(test_df_rajasthan)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)
gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")
rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# |-6.17252171191365...|     0.0|[-10.0,14.0,31.0,...|
# |-6.17252171191365...|     0.0|[-10.0,20.0,0.0,1...|
# |-6.17252171191365...|     0.0|[-10.0,22.0,2.0,2...|
# |-6.17252171191365...|     0.0|[-9.0,5.0,0.0,10....|
# | 0.08245224860819547|     0.0|[-9.0,10.0,100.0,...|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 1.25999
# R Squared (R2) on test data = 0.414942

# %%
gbt_model = gbt.fit(train_df_shillong)
gbt_predictions = gbt_model.transform(test_df_shillong)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)
gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")
rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# | 0.01509057360845517|     0.0|[-2.0,9.0,0.0,22....|
# | 0.04883296545798776|     0.0|[-1.0,16.0,0.0,25...|
# | 0.04883296545798776|     0.0|[-1.0,17.0,0.0,28...|
# |0.007544415022873...|     0.0|[0.0,6.0,1.0,45.0...|
# |0.010976293223667584|     0.0|[0.0,12.0,2.0,19....|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 2.44852
# R Squared (R2) on test data = 0.692014

# %%
gbt_model = gbt.fit(train_df_uttarakhand)
gbt_predictions = gbt_model.transform(test_df_uttarakhand)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)
gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")
rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# |1.681238055363480...|     0.0|[-11.0,8.0,23.0,1...|
# |1.681238055363480...|     0.0| [-9.0,0.0,8.0,10.0]|
# |1.681238055363480...|     0.0| [-8.0,0.0,4.0,10.0]|
# |1.681238055363480...|     0.0|[-8.0,0.0,22.0,10.0]|
# |1.681238055363480...|     0.0|[-8.0,0.0,23.0,10.0]|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 0.648967
# R Squared (R2) on test data = 0.781051

# %%
gbt_model = gbt.fit(train_df_vellore)
gbt_predictions = gbt_model.transform(test_df_vellore)
gbt_predictions.select('prediction', 'precipMM', 'features').show(5)
gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="rmse")
rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)

gbt_evaluator = RegressionEvaluator(
    labelCol="precipMM", predictionCol="prediction", metricName="r2")

r2 = gbt_evaluator.evaluate(gbt_predictions)
print("R Squared (R2) on test data = %g" % r2)
# Out:
# +--------------------+--------+--------------------+
# |          prediction|precipMM|            features|
# +--------------------+--------+--------------------+
# |0.028240107901504816|     0.0|[4.2,17.0,26.0,87...|
# | 0.16925450221212485|     0.0|[4.2,17.0,66.0,90...|
# | -0.2341065395571461|     0.0|[4.2,18.0,34.0,91...|
# | 0.04938431749321476|     0.0|[4.2,18.0,49.0,83...|
# | 0.07881747214169538|     0.0|[4.2,18.0,52.0,88...|
# +--------------------+--------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 0.847328
# R Squared (R2) on test data = 0.567606
